# %%
# %matplotlib widget
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
print("hello")
# Out:
# hello

# %%
def f(x, a):
    print(x, a)
interact(f, x=3.5, a=True)
# Out:
# 3.5 True
# <function __main__.f(x, a)>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,5,30)

def f(k,title):
    y = np.sin(k*x*0.8)
    plt.plot(x,y)
    plt.show()

print('..')
w = interactive(f,k=3.0,title=["Hello","world"])
print(w)
print(w.children)
print('..')
w
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig = plt.figure(figsize=(5,5))

img=mpimg.imread('img/relhel_1p0_re_1Dfiterr.png')

def onclick(event):
    ix, iy = event.xdata, event.ydata
    print(ix, iy)

cid = fig.canvas.mpl_connect('button_press_event', onclick)

print(cid)
imgplot = plt.imshow(img)
plt.show()
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7c2dde7b2365> in <module>
#       5 fig = plt.figure(figsize=(5,5))
#       6
# ----> 7 img=mpimg.imread('img/relhel_1p0_re_1Dfiterr.png')
#       8
#       9 def onclick(event):
#
# /usr/lib64/python3.10/site-packages/matplotlib/image.py in imread(fname, format)
#    1558                     response = io.BytesIO(response.read())
#    1559                 return imread(response, format=ext)
# -> 1560     with img_open(fname) as image:
#    1561         return (_pil_png_to_float_array(image)
#    1562                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/lib64/python3.10/site-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     107         if isPath(fp):
#     108             # filename
# --> 109             self.fp = open(fp, "rb")
#     110             self.filename = fp
#     111             self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img/relhel_1p0_re_1Dfiterr.png'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
t= np.arange(0,1,0.01)
def pltsin(f):
    print(f)
    plt.plot(t,np.sin(2*np.pi*t*f))
    plt.show()
interact(pltsin,f=FloatSlider(min=1, max=23, step=1,continuous_update=False))

# %% [markdown]
# $$ x^2$$

# %%
pltsin(3)
