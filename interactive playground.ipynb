# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
print("hello")
# Out:
# hello

# %%
def f(x, a):
    print(x, a)
interact(f, x=3.5, a=True)
# Out:
# interactive(children=(FloatSlider(value=3.5, description='x', max=10.5, min=-3.5), Checkbox(value=True, descri…
# <function __main__.f(x, a)>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,5,30)

def f(k,title):
    y = np.sin(k*x)
    plt.plot(x,y)
    plt.show()

interact(f,k=3.0,title=["Hello","world"],continuous_update=False)
# Out:
# interactive(children=(FloatSlider(value=3.0, description='k', max=9.0, min=-3.0), Dropdown(description='title'…
# <function __main__.f(k, title)>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig = plt.figure(figsize=(5,5))

img=mpimg.imread('img/relhel_1p0_re_1Dfiterr.png')

def onclick(event):
    ix, iy = event.xdata, event.ydata
    print(ix, iy)

cid = fig.canvas.mpl_connect('button_press_event', onclick)

print(cid)
imgplot = plt.imshow(img)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# 7

# %%
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
t= np.arange(0,1,0.01)
def pltsin(f):
    print(f)
    plt.plot(t,np.sin(2*np.pi*t*f))
    plt.show()
interact(pltsin,f=FloatSlider(min=1, max=23, step=1,continuous_update=False))
# Out:
# interactive(children=(FloatSlider(value=1.0, continuous_update=False, description='f', max=23.0, min=1.0, step…
# <function __main__.pltsin(f)>

# %% [markdown]
# $$ x^2$$

# %%
pltsin(3)
# Out:
# 3
