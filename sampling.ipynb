# %%
import numpy as np
ln = np.log
from numpy import * # :)
import json
from time import sleep
import matplotlib.pyplot as plt
import os
import csv
import collections
from IPython.display import clear_output
import scipy.optimize as opti
import scipy.stats
import functools
from dataclasses import dataclass
import typing
import itertools as it
import statistics as stat
import yaml

# %%
print("\n".join(sorted(filter(lambda x : os.path.isdir(x) and not x.startswith("."), os.listdir()))))
# Out:
# A_correct_hel_half_201
# A_correct_hel_half_202
# A_correct_hel_half_203
# A_correct_hel_half_204
# A_correct_hel_half_205
# A_correct_hel_half_206
# A_correct_hel_half_207
# A_correct_hel_half_208
# A_correct_hel_half_209
# A_correct_hel_half_210
# A_correct_hel_half_211
# A_correct_hel_half_212
# A_correct_hel_half_213
# A_correct_hel_half_214
# A_correct_hel_half_215
# A_correct_hel_half_216
# A_correct_hel_half_217
# A_correct_hel_half_218
# A_correct_hel_half_219
# A_correct_hel_half_220
# A_correct_hel_half_221
# A_correct_hel_half_222
# A_correct_hel_half_223
# A_correct_hel_half_224
# A_correct_hel_half_225
# A_correct_hel_half_226
# A_correct_hel_half_227
# A_correct_hel_half_228
# A_correct_hel_half_229
# A_correct_hel_half_230
# A_correct_hel_half_231
# A_correct_hel_half_232
# A_correct_hel_half_233
# A_correct_hel_half_234
# A_correct_hel_half_235
# A_correct_hel_half_236
# A_correct_hel_half_237
# A_correct_hel_half_238
# A_correct_hel_half_239
# A_correct_hel_half_240
# A_correct_hel_half_241
# A_correct_hel_half_242
# A_correct_hel_half_243
# A_correct_hel_half_244
# A_correct_hel_half_245
# A_correct_hel_half_246
# A_correct_hel_half_247
# A_correct_hel_half_248
# A_correct_hel_half_249
# A_correct_hel_half_250
# A_correct_hel_half_251
# A_correct_hel_half_252
# A_correct_hel_half_253
# A_correct_hel_half_254
# A_correct_hel_half_255
# A_correct_hel_half_256
# A_correct_hel_half_257
# A_correct_hel_half_258
# A_correct_hel_half_259
# A_correct_hel_half_260
# A_correct_hel_half_261
# A_correct_hel_half_262
# A_correct_hel_half_263
# A_correct_hel_half_264
# A_correct_hel_half_265
# A_correct_hel_half_266
# A_correct_hel_half_267
# A_correct_hel_half_268
# A_correct_hel_half_269
# A_correct_hel_half_270
# A_correct_hel_half_271
# A_correct_hel_half_272
# A_correct_hel_half_273
# A_correct_hel_half_274
# A_correct_hel_half_275
# A_correct_hel_half_276
# A_correct_hel_half_277
# A_correct_hel_half_278
# A_correct_hel_half_279
# A_correct_hel_half_280
# A_correct_hel_half_281
# A_correct_hel_half_282
# A_correct_hel_half_283
# A_correct_hel_half_284
# A_correct_hel_half_285
# A_correct_hel_half_286
# A_correct_hel_half_287
# A_correct_hel_half_288
# A_correct_hel_half_289
# A_correct_hel_half_290
# A_correct_hel_half_291
# A_correct_hel_half_292
# A_correct_hel_half_293
# A_correct_hel_half_294
# A_correct_hel_half_295
# A_correct_hel_half_296
# A_correct_hel_half_297
# A_correct_hel_half_298
# A_correct_hel_half_299
# A_correct_hel_half_300
# A_correct_hel_one_1
# A_correct_hel_one_10
# A_correct_hel_one_100
# A_correct_hel_one_11
# A_correct_hel_one_12
# A_correct_hel_one_13
# A_correct_hel_one_14
# A_correct_hel_one_15
# A_correct_hel_one_16
# A_correct_hel_one_17
# A_correct_hel_one_18
# A_correct_hel_one_19
# A_correct_hel_one_2
# A_correct_hel_one_20
# A_correct_hel_one_21
# A_correct_hel_one_22
# A_correct_hel_one_23
# A_correct_hel_one_24
# A_correct_hel_one_25
# A_correct_hel_one_26
# A_correct_hel_one_27
# A_correct_hel_one_28
# A_correct_hel_one_29
# A_correct_hel_one_3
# A_correct_hel_one_30
# A_correct_hel_one_31
# A_correct_hel_one_32
# A_correct_hel_one_33
# A_correct_hel_one_34
# A_correct_hel_one_35
# A_correct_hel_one_36
# A_correct_hel_one_37
# A_correct_hel_one_38
# A_correct_hel_one_39
# A_correct_hel_one_4
# A_correct_hel_one_40
# A_correct_hel_one_41
# A_correct_hel_one_42
# A_correct_hel_one_43
# A_correct_hel_one_44
# A_correct_hel_one_45
# A_correct_hel_one_46
# A_correct_hel_one_47
# A_correct_hel_one_48
# A_correct_hel_one_49
# A_correct_hel_one_5
# A_correct_hel_one_50
# A_correct_hel_one_51
# A_correct_hel_one_52
# A_correct_hel_one_53
# A_correct_hel_one_54
# A_correct_hel_one_55
# A_correct_hel_one_56
# A_correct_hel_one_57
# A_correct_hel_one_58
# A_correct_hel_one_59
# A_correct_hel_one_6
# A_correct_hel_one_60
# A_correct_hel_one_61
# A_correct_hel_one_62
# A_correct_hel_one_63
# A_correct_hel_one_64
# A_correct_hel_one_65
# A_correct_hel_one_66
# A_correct_hel_one_67
# A_correct_hel_one_68
# A_correct_hel_one_69
# A_correct_hel_one_7
# A_correct_hel_one_70
# A_correct_hel_one_71
# A_correct_hel_one_72
# A_correct_hel_one_73
# A_correct_hel_one_74
# A_correct_hel_one_75
# A_correct_hel_one_76
# A_correct_hel_one_77
# A_correct_hel_one_78
# A_correct_hel_one_79
# A_correct_hel_one_8
# A_correct_hel_one_80
# A_correct_hel_one_81
# A_correct_hel_one_82
# A_correct_hel_one_83
# A_correct_hel_one_84
# A_correct_hel_one_85
# A_correct_hel_one_86
# A_correct_hel_one_87
# A_correct_hel_one_88
# A_correct_hel_one_89
# A_correct_hel_one_9
# A_correct_hel_one_90
# A_correct_hel_one_91
# A_correct_hel_one_92
# A_correct_hel_one_93
# A_correct_hel_one_94
# A_correct_hel_one_95
# A_correct_hel_one_96
# A_correct_hel_one_97
# A_correct_hel_one_98
# A_correct_hel_one_99
# A_correct_hel_zero_101
# A_correct_hel_zero_102
# A_correct_hel_zero_103
# A_correct_hel_zero_104
# A_correct_hel_zero_105
# A_correct_hel_zero_106
# A_correct_hel_zero_107
# A_correct_hel_zero_108
# A_correct_hel_zero_109
# A_correct_hel_zero_110
# A_correct_hel_zero_111
# A_correct_hel_zero_112
# A_correct_hel_zero_113
# A_correct_hel_zero_114
# A_correct_hel_zero_115
# A_correct_hel_zero_116
# A_correct_hel_zero_117
# A_correct_hel_zero_118
# A_correct_hel_zero_119
# A_correct_hel_zero_120
# A_correct_hel_zero_121
# A_correct_hel_zero_122
# A_correct_hel_zero_123
# A_correct_hel_zero_124
# A_correct_hel_zero_125
# A_correct_hel_zero_126
# A_correct_hel_zero_127
# A_correct_hel_zero_128
# A_correct_hel_zero_129
# A_correct_hel_zero_130
# A_correct_hel_zero_131
# A_correct_hel_zero_132
# A_correct_hel_zero_133
# A_correct_hel_zero_134
# A_correct_hel_zero_135
# A_correct_hel_zero_136
# A_correct_hel_zero_137
# A_correct_hel_zero_138
# A_correct_hel_zero_139
# A_correct_hel_zero_140
# A_correct_hel_zero_141
# A_correct_hel_zero_142
# A_correct_hel_zero_143
# A_correct_hel_zero_144
# A_correct_hel_zero_145
# A_correct_hel_zero_146
# A_correct_hel_zero_147
# A_correct_hel_zero_148
# A_correct_hel_zero_149
# A_correct_hel_zero_150
# A_correct_hel_zero_151
# A_correct_hel_zero_152
# A_correct_hel_zero_153
# A_correct_hel_zero_154
# A_correct_hel_zero_155
# A_correct_hel_zero_156
# A_correct_hel_zero_157
# A_correct_hel_zero_158
# A_correct_hel_zero_159
# A_correct_hel_zero_160
# A_correct_hel_zero_161
# A_correct_hel_zero_162
# A_correct_hel_zero_163
# A_correct_hel_zero_164
# A_correct_hel_zero_165
# A_correct_hel_zero_166
# A_correct_hel_zero_167
# A_correct_hel_zero_168
# A_correct_hel_zero_169
# A_correct_hel_zero_170
# A_correct_hel_zero_171
# A_correct_hel_zero_172
# A_correct_hel_zero_173
# A_correct_hel_zero_174
# A_correct_hel_zero_175
# A_correct_hel_zero_176
# A_correct_hel_zero_177
# A_correct_hel_zero_178
# A_correct_hel_zero_179
# A_correct_hel_zero_180
# A_correct_hel_zero_181
# A_correct_hel_zero_182
# A_correct_hel_zero_183
# A_correct_hel_zero_184
# A_correct_hel_zero_185
# A_correct_hel_zero_186
# A_correct_hel_zero_187
# A_correct_hel_zero_188
# A_correct_hel_zero_189
# A_correct_hel_zero_190
# A_correct_hel_zero_191
# A_correct_hel_zero_192
# A_correct_hel_zero_193
# A_correct_hel_zero_194
# A_correct_hel_zero_195
# A_correct_hel_zero_196
# A_correct_hel_zero_197
# A_correct_hel_zero_198
# A_correct_hel_zero_199
# A_correct_hel_zero_200
# A_hel_half_31
# A_hel_half_32
# A_hel_half_33
# A_hel_half_34
# A_hel_half_35
# A_hel_half_36
# A_hel_half_37
# A_hel_half_38
# A_hel_half_39
# A_hel_half_40
# A_hel_half_41
# A_hel_half_42
# A_hel_half_43
# A_hel_half_44
# A_hel_half_45
# A_hel_half_46
# A_hel_half_47
# A_hel_half_48
# A_hel_half_49
# A_hel_half_50
# A_hel_half_51
# A_hel_half_52
# A_hel_half_53
# A_hel_half_54
# A_hel_half_55
# A_hel_half_56
# A_hel_half_57
# A_hel_half_58
# A_hel_half_59
# A_hel_half_60
# A_hel_half_70
# A_hel_half_72
# A_hel_half_84
# A_hel_one_
# A_hel_one_1
# A_hel_one_10
# A_hel_one_106
# A_hel_one_109
# A_hel_one_11
# A_hel_one_117
# A_hel_one_118
# A_hel_one_12
# A_hel_one_124
# A_hel_one_13
# A_hel_one_133
# A_hel_one_14
# A_hel_one_147
# A_hel_one_15
# A_hel_one_16
# A_hel_one_17
# A_hel_one_18
# A_hel_one_19
# A_hel_one_2
# A_hel_one_20
# A_hel_one_21
# A_hel_one_22
# A_hel_one_23
# A_hel_one_24
# A_hel_one_25
# A_hel_one_26
# A_hel_one_27
# A_hel_one_28
# A_hel_one_29
# A_hel_one_3
# A_hel_one_4
# A_hel_one_5
# A_hel_one_6
# A_hel_one_7
# A_hel_one_8
# A_hel_one_9
# A_hel_one_90
# A_hel_one_93
# A_hel_zero_1
# A_hel_zero_10
# A_hel_zero_11
# A_hel_zero_12
# A_hel_zero_13
# A_hel_zero_14
# A_hel_zero_15
# A_hel_zero_16
# A_hel_zero_17
# A_hel_zero_18
# A_hel_zero_19
# A_hel_zero_2
# A_hel_zero_20
# A_hel_zero_21
# A_hel_zero_22
# A_hel_zero_23
# A_hel_zero_24
# A_hel_zero_25
# A_hel_zero_26
# A_hel_zero_27
# A_hel_zero_28
# A_hel_zero_29
# A_hel_zero_3
# A_hel_zero_30
# A_hel_zero_32
# A_hel_zero_33
# A_hel_zero_4
# A_hel_zero_46
# A_hel_zero_5
# A_hel_zero_6
# A_hel_zero_7
# A_hel_zero_8
# A_hel_zero_9
# A_var_hel_1
# A_var_hel_10
# A_var_hel_10-1
# A_var_hel_10-10
# A_var_hel_10-11
# A_var_hel_10-13
# A_var_hel_10-14
# A_var_hel_10-16
# A_var_hel_10-17
# A_var_hel_10-201
# A_var_hel_10-202
# A_var_hel_10-203
# A_var_hel_10-204
# A_var_hel_10-205
# A_var_hel_10-206
# A_var_hel_10-207
# A_var_hel_10-208
# A_var_hel_10-209
# A_var_hel_10-21
# A_var_hel_10-210
# A_var_hel_10-211
# A_var_hel_10-212
# A_var_hel_10-213
# A_var_hel_10-214
# A_var_hel_10-215
# A_var_hel_10-216
# A_var_hel_10-217
# A_var_hel_10-218
# A_var_hel_10-219
# A_var_hel_10-22
# A_var_hel_10-220
# A_var_hel_10-221
# A_var_hel_10-222
# A_var_hel_10-223
# A_var_hel_10-224
# A_var_hel_10-225
# A_var_hel_10-226
# A_var_hel_10-227
# A_var_hel_10-228
# A_var_hel_10-229
# A_var_hel_10-23
# A_var_hel_10-230
# A_var_hel_10-231
# A_var_hel_10-232
# A_var_hel_10-233
# A_var_hel_10-234
# A_var_hel_10-235
# A_var_hel_10-236
# A_var_hel_10-237
# A_var_hel_10-238
# A_var_hel_10-239
# A_var_hel_10-24
# A_var_hel_10-240
# A_var_hel_10-241
# A_var_hel_10-242
# A_var_hel_10-243
# A_var_hel_10-244
# A_var_hel_10-245
# A_var_hel_10-246
# A_var_hel_10-247
# A_var_hel_10-248
# A_var_hel_10-249
# A_var_hel_10-25
# A_var_hel_10-250
# A_var_hel_10-27
# A_var_hel_10-28
# A_var_hel_10-29
# A_var_hel_10-3
# A_var_hel_10-30
# A_var_hel_10-31
# A_var_hel_10-32
# A_var_hel_10-33
# A_var_hel_10-35
# A_var_hel_10-37
# A_var_hel_10-39
# A_var_hel_10-4
# A_var_hel_10-401
# A_var_hel_10-402
# A_var_hel_10-403
# A_var_hel_10-404
# A_var_hel_10-405
# A_var_hel_10-406
# A_var_hel_10-407
# A_var_hel_10-408
# A_var_hel_10-409
# A_var_hel_10-410
# A_var_hel_10-411
# A_var_hel_10-412
# A_var_hel_10-413
# A_var_hel_10-414
# A_var_hel_10-415
# A_var_hel_10-416
# A_var_hel_10-417
# A_var_hel_10-418
# A_var_hel_10-419
# A_var_hel_10-420
# A_var_hel_10-421
# A_var_hel_10-422
# A_var_hel_10-423
# A_var_hel_10-424
# A_var_hel_10-425
# A_var_hel_10-426
# A_var_hel_10-427
# A_var_hel_10-428
# A_var_hel_10-429
# A_var_hel_10-430
# A_var_hel_10-431
# A_var_hel_10-432
# A_var_hel_10-433
# A_var_hel_10-434
# A_var_hel_10-435
# A_var_hel_10-436
# A_var_hel_10-437
# A_var_hel_10-438
# A_var_hel_10-439
# A_var_hel_10-440
# A_var_hel_10-441
# A_var_hel_10-442
# A_var_hel_10-443
# A_var_hel_10-444
# A_var_hel_10-445
# A_var_hel_10-446
# A_var_hel_10-447
# A_var_hel_10-448
# A_var_hel_10-449
# A_var_hel_10-450
# A_var_hel_10-46
# A_var_hel_10-5
# A_var_hel_10-50
# A_var_hel_10-6
# A_var_hel_10-7
# A_var_hel_10-8
# A_var_hel_10-9
# A_var_hel_101
# A_var_hel_102
# A_var_hel_104
# A_var_hel_105
# A_var_hel_106
# A_var_hel_107
# A_var_hel_108
# A_var_hel_11
# A_var_hel_111
# A_var_hel_112
# A_var_hel_113
# A_var_hel_114
# A_var_hel_115
# A_var_hel_116
# A_var_hel_117
# A_var_hel_119
# A_var_hel_12
# A_var_hel_122
# A_var_hel_123
# A_var_hel_124
# A_var_hel_126
# A_var_hel_127
# A_var_hel_129
# A_var_hel_13
# A_var_hel_130
# A_var_hel_131
# A_var_hel_133
# A_var_hel_134
# A_var_hel_135
# A_var_hel_137
# A_var_hel_139
# A_var_hel_14
# A_var_hel_140
# A_var_hel_143
# A_var_hel_144
# A_var_hel_145
# A_var_hel_146
# A_var_hel_147
# A_var_hel_148
# A_var_hel_15
# A_var_hel_152
# A_var_hel_155
# A_var_hel_156
# A_var_hel_157
# A_var_hel_158
# A_var_hel_160
# A_var_hel_161
# A_var_hel_162
# A_var_hel_166
# A_var_hel_168
# A_var_hel_17
# A_var_hel_170
# A_var_hel_171
# A_var_hel_172
# A_var_hel_173
# A_var_hel_174
# A_var_hel_175
# A_var_hel_176
# A_var_hel_178
# A_var_hel_179
# A_var_hel_180
# A_var_hel_181
# A_var_hel_182
# A_var_hel_183
# A_var_hel_184
# A_var_hel_185
# A_var_hel_187
# A_var_hel_188
# A_var_hel_189
# A_var_hel_19
# A_var_hel_190
# A_var_hel_191
# A_var_hel_192
# A_var_hel_194
# A_var_hel_197
# A_var_hel_2
# A_var_hel_20
# A_var_hel_201
# A_var_hel_202
# A_var_hel_203
# A_var_hel_204
# A_var_hel_205
# A_var_hel_207
# A_var_hel_208
# A_var_hel_209
# A_var_hel_21
# A_var_hel_210
# A_var_hel_211
# A_var_hel_212
# A_var_hel_213
# A_var_hel_214
# A_var_hel_215
# A_var_hel_216
# A_var_hel_217
# A_var_hel_218
# A_var_hel_219
# A_var_hel_220
# A_var_hel_221
# A_var_hel_222
# A_var_hel_223
# A_var_hel_224
# A_var_hel_225
# A_var_hel_226
# A_var_hel_227
# A_var_hel_228
# A_var_hel_229
# A_var_hel_23
# A_var_hel_230
# A_var_hel_231
# A_var_hel_232
# A_var_hel_233
# A_var_hel_234
# A_var_hel_235
# A_var_hel_236
# A_var_hel_237
# A_var_hel_238
# A_var_hel_239
# A_var_hel_24
# A_var_hel_240
# A_var_hel_241
# A_var_hel_242
# A_var_hel_244
# A_var_hel_245
# A_var_hel_247
# A_var_hel_248
# A_var_hel_249
# A_var_hel_25
# A_var_hel_25-251
# A_var_hel_25-252
# A_var_hel_25-253
# A_var_hel_25-254
# A_var_hel_25-255
# A_var_hel_25-256
# A_var_hel_25-257
# A_var_hel_25-258
# A_var_hel_25-259
# A_var_hel_25-260
# A_var_hel_25-261
# A_var_hel_25-262
# A_var_hel_25-263
# A_var_hel_25-264
# A_var_hel_25-265
# A_var_hel_25-266
# A_var_hel_25-267
# A_var_hel_25-268
# A_var_hel_25-269
# A_var_hel_25-270
# A_var_hel_25-271
# A_var_hel_25-272
# A_var_hel_25-273
# A_var_hel_25-274
# A_var_hel_25-275
# A_var_hel_25-276
# A_var_hel_25-277
# A_var_hel_25-278
# A_var_hel_25-279
# A_var_hel_25-280
# A_var_hel_25-281
# A_var_hel_25-282
# A_var_hel_25-283
# A_var_hel_25-284
# A_var_hel_25-285
# A_var_hel_25-286
# A_var_hel_25-287
# A_var_hel_25-288
# A_var_hel_25-289
# A_var_hel_25-290
# A_var_hel_25-291
# A_var_hel_25-292
# A_var_hel_25-293
# A_var_hel_25-294
# A_var_hel_25-295
# A_var_hel_25-296
# A_var_hel_25-297
# A_var_hel_25-298
# A_var_hel_25-299
# A_var_hel_25-300
# A_var_hel_25-451
# A_var_hel_25-452
# A_var_hel_25-453
# A_var_hel_25-454
# A_var_hel_25-455
# A_var_hel_25-456
# A_var_hel_25-457
# A_var_hel_25-458
# A_var_hel_25-459
# A_var_hel_25-460
# A_var_hel_25-461
# A_var_hel_25-462
# A_var_hel_25-463
# A_var_hel_25-464
# A_var_hel_25-465
# A_var_hel_25-466
# A_var_hel_25-467
# A_var_hel_25-468
# A_var_hel_25-469
# A_var_hel_25-470
# A_var_hel_25-471
# A_var_hel_25-472
# A_var_hel_25-473
# A_var_hel_25-474
# A_var_hel_25-475
# A_var_hel_25-476
# A_var_hel_25-477
# A_var_hel_25-478
# A_var_hel_25-479
# A_var_hel_25-480
# A_var_hel_25-481
# A_var_hel_25-482
# A_var_hel_25-483
# A_var_hel_25-484
# A_var_hel_25-485
# A_var_hel_25-486
# A_var_hel_25-487
# A_var_hel_25-488
# A_var_hel_25-489
# A_var_hel_25-490
# A_var_hel_25-491
# A_var_hel_25-492
# A_var_hel_25-493
# A_var_hel_25-494
# A_var_hel_25-495
# A_var_hel_25-496
# A_var_hel_25-497
# A_var_hel_25-498
# A_var_hel_25-499
# A_var_hel_25-500
# A_var_hel_25-51
# A_var_hel_25-52
# A_var_hel_25-53
# A_var_hel_25-55
# A_var_hel_25-56
# A_var_hel_25-58
# A_var_hel_25-59
# A_var_hel_25-60
# A_var_hel_25-62
# A_var_hel_25-63
# A_var_hel_25-65
# A_var_hel_25-66
# A_var_hel_25-67
# A_var_hel_25-73
# A_var_hel_25-74
# A_var_hel_25-75
# A_var_hel_25-78
# A_var_hel_25-79
# A_var_hel_25-81
# A_var_hel_25-85
# A_var_hel_25-87
# A_var_hel_25-90
# A_var_hel_25-92
# A_var_hel_25-95
# A_var_hel_25-96
# A_var_hel_25-97
# A_var_hel_25-98
# A_var_hel_25-99
# A_var_hel_252
# A_var_hel_254
# A_var_hel_255
# A_var_hel_256
# A_var_hel_258
# A_var_hel_259
# A_var_hel_260
# A_var_hel_261
# A_var_hel_264
# A_var_hel_265
# A_var_hel_267
# A_var_hel_268
# A_var_hel_269
# A_var_hel_270
# A_var_hel_271
# A_var_hel_272
# A_var_hel_273
# A_var_hel_274
# A_var_hel_275
# A_var_hel_276
# A_var_hel_277
# A_var_hel_278
# A_var_hel_279
# A_var_hel_28
# A_var_hel_280
# A_var_hel_282
# A_var_hel_285
# A_var_hel_286
# A_var_hel_288
# A_var_hel_289
# A_var_hel_29
# A_var_hel_290
# A_var_hel_291
# A_var_hel_292
# A_var_hel_294
# A_var_hel_296
# A_var_hel_297
# A_var_hel_299
# A_var_hel_3
# A_var_hel_300
# A_var_hel_301
# A_var_hel_302
# A_var_hel_304
# A_var_hel_305
# A_var_hel_306
# A_var_hel_307
# A_var_hel_308
# A_var_hel_309
# A_var_hel_31
# A_var_hel_310
# A_var_hel_311
# A_var_hel_312
# A_var_hel_313
# A_var_hel_314
# A_var_hel_315
# A_var_hel_316
# A_var_hel_317
# A_var_hel_318
# A_var_hel_319
# A_var_hel_32
# A_var_hel_320
# A_var_hel_322
# A_var_hel_323
# A_var_hel_325
# A_var_hel_33
# A_var_hel_330
# A_var_hel_331
# A_var_hel_332
# A_var_hel_333
# A_var_hel_334
# A_var_hel_335
# A_var_hel_339
# A_var_hel_34
# A_var_hel_340
# A_var_hel_343
# A_var_hel_345
# A_var_hel_346
# A_var_hel_347
# A_var_hel_348
# A_var_hel_349
# A_var_hel_35
# A_var_hel_352
# A_var_hel_353
# A_var_hel_355
# A_var_hel_357
# A_var_hel_358
# A_var_hel_359
# A_var_hel_36
# A_var_hel_361
# A_var_hel_362
# A_var_hel_365
# A_var_hel_367
# A_var_hel_37
# A_var_hel_374
# A_var_hel_377
# A_var_hel_378
# A_var_hel_38
# A_var_hel_386
# A_var_hel_388
# A_var_hel_39
# A_var_hel_390
# A_var_hel_392
# A_var_hel_393
# A_var_hel_394
# A_var_hel_395
# A_var_hel_397
# A_var_hel_399
# A_var_hel_4
# A_var_hel_40
# A_var_hel_402
# A_var_hel_404
# A_var_hel_406
# A_var_hel_408
# A_var_hel_41
# A_var_hel_411
# A_var_hel_412
# A_var_hel_415
# A_var_hel_418
# A_var_hel_42
# A_var_hel_421
# A_var_hel_423
# A_var_hel_425
# A_var_hel_426
# A_var_hel_428
# A_var_hel_43
# A_var_hel_430
# A_var_hel_431
# A_var_hel_433
# A_var_hel_435
# A_var_hel_438
# A_var_hel_439
# A_var_hel_440
# A_var_hel_443
# A_var_hel_444
# A_var_hel_449
# A_var_hel_45
# A_var_hel_453
# A_var_hel_460
# A_var_hel_461
# A_var_hel_467
# A_var_hel_468
# A_var_hel_47
# A_var_hel_479
# A_var_hel_482
# A_var_hel_485
# A_var_hel_487
# A_var_hel_493
# A_var_hel_5
# A_var_hel_500
# A_var_hel_501
# A_var_hel_502
# A_var_hel_51
# A_var_hel_511
# A_var_hel_514
# A_var_hel_517
# A_var_hel_528
# A_var_hel_531
# A_var_hel_54
# A_var_hel_541
# A_var_hel_542
# A_var_hel_545
# A_var_hel_546
# A_var_hel_548
# A_var_hel_552
# A_var_hel_553
# A_var_hel_556
# A_var_hel_558
# A_var_hel_56
# A_var_hel_563
# A_var_hel_564
# A_var_hel_566
# A_var_hel_567
# A_var_hel_568
# A_var_hel_57
# A_var_hel_573
# A_var_hel_581
# A_var_hel_586
# A_var_hel_587
# A_var_hel_589
# A_var_hel_59
# A_var_hel_590
# A_var_hel_599
# A_var_hel_6
# A_var_hel_60
# A_var_hel_602
# A_var_hel_603
# A_var_hel_607
# A_var_hel_61
# A_var_hel_610
# A_var_hel_614
# A_var_hel_626
# A_var_hel_63
# A_var_hel_636
# A_var_hel_64
# A_var_hel_640
# A_var_hel_647
# A_var_hel_65
# A_var_hel_650
# A_var_hel_655
# A_var_hel_66
# A_var_hel_661
# A_var_hel_662
# A_var_hel_667
# A_var_hel_67
# A_var_hel_69
# A_var_hel_71
# A_var_hel_74
# A_var_hel_75
# A_var_hel_75-103
# A_var_hel_75-104
# A_var_hel_75-106
# A_var_hel_75-107
# A_var_hel_75-108
# A_var_hel_75-109
# A_var_hel_75-111
# A_var_hel_75-112
# A_var_hel_75-115
# A_var_hel_75-120
# A_var_hel_75-121
# A_var_hel_75-123
# A_var_hel_75-126
# A_var_hel_75-129
# A_var_hel_75-131
# A_var_hel_75-134
# A_var_hel_75-135
# A_var_hel_75-139
# A_var_hel_75-143
# A_var_hel_75-144
# A_var_hel_75-145
# A_var_hel_75-146
# A_var_hel_75-148
# A_var_hel_75-301
# A_var_hel_75-302
# A_var_hel_75-303
# A_var_hel_75-304
# A_var_hel_75-305
# A_var_hel_75-306
# A_var_hel_75-307
# A_var_hel_75-308
# A_var_hel_75-309
# A_var_hel_75-310
# A_var_hel_75-311
# A_var_hel_75-312
# A_var_hel_75-313
# A_var_hel_75-314
# A_var_hel_75-315
# A_var_hel_75-316
# A_var_hel_75-317
# A_var_hel_75-318
# A_var_hel_75-319
# A_var_hel_75-320
# A_var_hel_75-321
# A_var_hel_75-322
# A_var_hel_75-323
# A_var_hel_75-324
# A_var_hel_75-325
# A_var_hel_75-326
# A_var_hel_75-327
# A_var_hel_75-328
# A_var_hel_75-329
# A_var_hel_75-330
# A_var_hel_75-331
# A_var_hel_75-332
# A_var_hel_75-333
# A_var_hel_75-334
# A_var_hel_75-335
# A_var_hel_75-336
# A_var_hel_75-337
# A_var_hel_75-338
# A_var_hel_75-339
# A_var_hel_75-340
# A_var_hel_75-341
# A_var_hel_75-342
# A_var_hel_75-343
# A_var_hel_75-344
# A_var_hel_75-345
# A_var_hel_75-346
# A_var_hel_75-347
# A_var_hel_75-348
# A_var_hel_75-349
# A_var_hel_75-350
# A_var_hel_75-501
# A_var_hel_75-502
# A_var_hel_75-503
# A_var_hel_75-504
# A_var_hel_75-505
# A_var_hel_75-506
# A_var_hel_75-507
# A_var_hel_75-508
# A_var_hel_75-509
# A_var_hel_75-510
# A_var_hel_75-511
# A_var_hel_75-512
# A_var_hel_75-513
# A_var_hel_75-514
# A_var_hel_75-515
# A_var_hel_75-516
# A_var_hel_75-517
# A_var_hel_75-518
# A_var_hel_75-519
# A_var_hel_75-520
# A_var_hel_75-521
# A_var_hel_75-522
# A_var_hel_75-523
# A_var_hel_75-524
# A_var_hel_75-525
# A_var_hel_75-526
# A_var_hel_75-527
# A_var_hel_75-528
# A_var_hel_75-529
# A_var_hel_75-530
# A_var_hel_75-531
# A_var_hel_75-532
# A_var_hel_75-533
# A_var_hel_75-534
# A_var_hel_75-535
# A_var_hel_75-536
# A_var_hel_75-537
# A_var_hel_75-538
# A_var_hel_75-539
# A_var_hel_75-540
# A_var_hel_75-541
# A_var_hel_75-542
# A_var_hel_75-543
# A_var_hel_75-544
# A_var_hel_75-545
# A_var_hel_75-546
# A_var_hel_75-547
# A_var_hel_75-548
# A_var_hel_75-549
# A_var_hel_75-550
# A_var_hel_76
# A_var_hel_78
# A_var_hel_80
# A_var_hel_83
# A_var_hel_84
# A_var_hel_85
# A_var_hel_86
# A_var_hel_90
# A_var_hel_90-151
# A_var_hel_90-156
# A_var_hel_90-157
# A_var_hel_90-159
# A_var_hel_90-161
# A_var_hel_90-164
# A_var_hel_90-171
# A_var_hel_90-176
# A_var_hel_90-183
# A_var_hel_90-184
# A_var_hel_90-189
# A_var_hel_90-190
# A_var_hel_90-193
# A_var_hel_90-200
# A_var_hel_90-351
# A_var_hel_90-352
# A_var_hel_90-353
# A_var_hel_90-354
# A_var_hel_90-355
# A_var_hel_90-356
# A_var_hel_90-357
# A_var_hel_90-358
# A_var_hel_90-359
# A_var_hel_90-360
# A_var_hel_90-361
# A_var_hel_90-362
# A_var_hel_90-363
# A_var_hel_90-364
# A_var_hel_90-365
# A_var_hel_90-366
# A_var_hel_90-367
# A_var_hel_90-368
# A_var_hel_90-369
# A_var_hel_90-370
# A_var_hel_90-371
# A_var_hel_90-372
# A_var_hel_90-373
# A_var_hel_90-374
# A_var_hel_90-375
# A_var_hel_90-376
# A_var_hel_90-377
# A_var_hel_90-378
# A_var_hel_90-379
# A_var_hel_90-380
# A_var_hel_90-381
# A_var_hel_90-382
# A_var_hel_90-383
# A_var_hel_90-384
# A_var_hel_90-385
# A_var_hel_90-386
# A_var_hel_90-387
# A_var_hel_90-388
# A_var_hel_90-389
# A_var_hel_90-390
# A_var_hel_90-391
# A_var_hel_90-392
# A_var_hel_90-393
# A_var_hel_90-394
# A_var_hel_90-395
# A_var_hel_90-396
# A_var_hel_90-397
# A_var_hel_90-398
# A_var_hel_90-399
# A_var_hel_90-400
# A_var_hel_90-551
# A_var_hel_90-552
# A_var_hel_90-553
# A_var_hel_90-554
# A_var_hel_90-555
# A_var_hel_90-556
# A_var_hel_90-557
# A_var_hel_90-558
# A_var_hel_90-559
# A_var_hel_90-560
# A_var_hel_90-561
# A_var_hel_90-562
# A_var_hel_90-563
# A_var_hel_90-564
# A_var_hel_90-565
# A_var_hel_90-566
# A_var_hel_90-567
# A_var_hel_90-568
# A_var_hel_90-569
# A_var_hel_90-570
# A_var_hel_90-571
# A_var_hel_90-572
# A_var_hel_90-573
# A_var_hel_90-574
# A_var_hel_90-575
# A_var_hel_90-576
# A_var_hel_90-577
# A_var_hel_90-578
# A_var_hel_90-579
# A_var_hel_90-580
# A_var_hel_90-581
# A_var_hel_90-582
# A_var_hel_90-583
# A_var_hel_90-584
# A_var_hel_90-585
# A_var_hel_90-586
# A_var_hel_90-587
# A_var_hel_90-588
# A_var_hel_90-589
# A_var_hel_90-590
# A_var_hel_90-591
# A_var_hel_90-592
# A_var_hel_90-593
# A_var_hel_90-594
# A_var_hel_90-595
# A_var_hel_90-596
# A_var_hel_90-597
# A_var_hel_90-598
# A_var_hel_90-599
# A_var_hel_90-600
# A_var_hel_92
# A_var_hel_93
# A_var_hel_95
# A_var_hel_96
# A_var_hel_97
# A_var_hel_98
# Anew_hel_one_1
# Anew_hel_one_10
# Anew_hel_one_18
# Anew_hel_one_21
# Anew_hel_one_27
# Anew_hel_one_28
# Anew_hel_one_5
# Anew_hel_one_7
# Anew_hel_one_8
# __pycache__
# crash_please_1
# crash_please_2
# detailed_A_1
# detailed_A_10
# detailed_A_11
# detailed_A_12
# detailed_A_13
# detailed_A_14
# detailed_A_15
# detailed_A_16
# detailed_A_17
# detailed_A_18
# detailed_A_19
# detailed_A_2
# detailed_A_20
# detailed_A_3
# detailed_A_4
# detailed_A_5
# detailed_A_6
# detailed_A_7
# detailed_A_8
# detailed_A_9
# detailed_B_21
# detailed_B_22
# detailed_B_23
# detailed_B_24
# detailed_B_25
# detailed_B_26
# detailed_B_27
# detailed_B_28
# detailed_B_29
# detailed_B_30
# detailed_B_31
# detailed_B_32
# detailed_B_33
# detailed_B_34
# detailed_B_35
# detailed_B_36
# detailed_B_37
# detailed_B_38
# detailed_B_39
# detailed_B_40
# detailed_C_41
# detailed_C_42
# detailed_C_43
# detailed_C_44
# detailed_C_45
# detailed_C_46
# detailed_C_47
# detailed_C_48
# detailed_C_49
# detailed_C_50
# detailed_C_51
# detailed_C_52
# detailed_C_53
# detailed_C_54
# detailed_C_55
# detailed_C_56
# detailed_C_57
# detailed_C_58
# detailed_C_59
# detailed_C_60
# detailed_D_61
# detailed_D_62
# detailed_D_63
# detailed_D_64
# detailed_D_65
# detailed_D_66
# detailed_D_67
# detailed_D_68
# detailed_D_69
# detailed_D_70
# detailed_D_71
# detailed_D_72
# detailed_D_73
# detailed_D_74
# detailed_D_75
# detailed_D_76
# detailed_D_77
# detailed_D_78
# detailed_D_79
# detailed_D_80
# detailed_E_1
# detailed_E_10
# detailed_E_2
# detailed_E_3
# detailed_E_4
# detailed_E_5
# detailed_E_6
# detailed_E_7
# detailed_E_8
# detailed_E_9
# detailed_F_11
# detailed_F_12
# detailed_F_13
# detailed_F_14
# detailed_F_15
# detailed_F_16
# detailed_F_17
# detailed_F_18
# detailed_F_19
# detailed_F_20
# different_params_long_final_1
# different_params_long_final_10
# different_params_long_final_2
# different_params_long_final_3
# different_params_long_final_4
# different_params_long_final_5
# different_params_long_final_6
# different_params_long_final_7
# different_params_long_final_8
# different_params_long_final_9
# even_more_tests_1
# even_more_tests_2
# even_more_tests_3
# even_more_tests_4
# force13_A_1
# force13_A_10
# force13_A_11
# force13_A_12
# force13_A_13
# force13_A_14
# force13_A_15
# force13_A_16
# force13_A_17
# force13_A_18
# force13_A_19
# force13_A_2
# force13_A_20
# force13_A_21
# force13_A_22
# force13_A_23
# force13_A_24
# force13_A_25
# force13_A_26
# force13_A_27
# force13_A_28
# force13_A_29
# force13_A_3
# force13_A_30
# force13_A_31
# force13_A_32
# force13_A_33
# force13_A_34
# force13_A_35
# force13_A_36
# force13_A_37
# force13_A_38
# force13_A_39
# force13_A_4
# force13_A_40
# force13_A_5
# force13_A_6
# force13_A_7
# force13_A_8
# force13_A_9
# force13_B_41
# force13_B_42
# force13_B_43
# force13_B_44
# force13_B_45
# force13_B_46
# force13_B_47
# force13_B_48
# force13_B_49
# force13_B_50
# force13_B_51
# force13_B_52
# force13_B_53
# force13_B_54
# force13_B_55
# force13_B_56
# force13_B_57
# force13_B_58
# force13_B_59
# force13_B_60
# force13_B_61
# force13_B_62
# force13_B_63
# force13_B_64
# force13_B_65
# force13_B_66
# force13_B_67
# force13_B_68
# force13_B_69
# force13_B_70
# force13_B_71
# force13_B_72
# force13_B_73
# force13_B_74
# force13_B_75
# force13_B_76
# force13_B_77
# force13_B_78
# force13_B_79
# force13_B_80
# force13_C_100
# force13_C_101
# force13_C_102
# force13_C_103
# force13_C_104
# force13_C_105
# force13_C_106
# force13_C_107
# force13_C_108
# force13_C_109
# force13_C_110
# force13_C_81
# force13_C_82
# force13_C_83
# force13_C_84
# force13_C_85
# force13_C_86
# force13_C_87
# force13_C_88
# force13_C_89
# force13_C_90
# force13_C_91
# force13_C_92
# force13_C_93
# force13_C_94
# force13_C_95
# force13_C_96
# force13_C_97
# force13_C_98
# force13_C_99
# garbage
# hel_half_51
# hel_half_52
# hel_half_53
# hel_half_54
# hel_half_55
# hel_half_56
# hel_half_57
# hel_half_58
# hel_half_59
# hel_half_60
# hel_half_61
# hel_half_62
# hel_half_63
# hel_half_64
# hel_half_65
# hel_half_66
# hel_half_67
# hel_half_68
# hel_half_69
# hel_half_70
# hel_half_71
# hel_half_72
# hel_half_73
# hel_half_74
# hel_half_75
# hel_half_76
# hel_half_77
# hel_half_A_1
# hel_half_A_2
# hel_half_A_200
# hel_half_A_201
# hel_half_A_3
# hel_half_A_300
# hel_half_A_301
# hel_half_A_400
# hel_half_A_401
# hel_half_A_500
# hel_half_A_501
# hel_half_A_600
# hel_half_A_601
# hel_half_A_700
# hel_half_A_701
# hel_half_A_800
# hel_half_A_801
# hel_half_A_900
# hel_half_A_901
# hel_half_higher_force_81
# hel_half_higher_force_82
# hel_half_higher_force_83
# hel_half_higher_force_84
# hel_half_higher_force_85
# hel_half_higher_force_86
# hel_half_higher_force_94
# hel_half_higher_force_95
# hel_one_1
# hel_one_10
# hel_one_11
# hel_one_12
# hel_one_13
# hel_one_14
# hel_one_15
# hel_one_16
# hel_one_17
# hel_one_18
# hel_one_19
# hel_one_2
# hel_one_20
# hel_one_21
# hel_one_22
# hel_one_23
# hel_one_24
# hel_one_25
# hel_one_26
# hel_one_27
# hel_one_28
# hel_one_29
# hel_one_3
# hel_one_30
# hel_one_31
# hel_one_32
# hel_one_33
# hel_one_34
# hel_one_35
# hel_one_36
# hel_one_37
# hel_one_38
# hel_one_39
# hel_one_4
# hel_one_40
# hel_one_41
# hel_one_42
# hel_one_43
# hel_one_44
# hel_one_45
# hel_one_46
# hel_one_47
# hel_one_48
# hel_one_49
# hel_one_5
# hel_one_50
# hel_one_6
# hel_one_7
# hel_one_8
# hel_one_9
# hel_zero_A_4
# hel_zero_A_5
# hel_zero_A_6
# high_Re_more_time_1
# high_Re_more_time_2
# high_Re_more_time_3
# high_Re_more_time_4
# high_Re_more_time_5
# high_Re_more_time_6
# high_Re_more_time_7
# high_Re_more_time_8
# high_Re_more_time_9
# high_Re_small_nx_again_1
# high_Re_small_nx_again_10
# high_Re_small_nx_again_11
# high_Re_small_nx_again_12
# high_Re_small_nx_again_13
# high_Re_small_nx_again_14
# high_Re_small_nx_again_15
# high_Re_small_nx_again_16
# high_Re_small_nx_again_17
# high_Re_small_nx_again_18
# high_Re_small_nx_again_19
# high_Re_small_nx_again_2
# high_Re_small_nx_again_20
# high_Re_small_nx_again_21
# high_Re_small_nx_again_22
# high_Re_small_nx_again_23
# high_Re_small_nx_again_24
# high_Re_small_nx_again_25
# high_Re_small_nx_again_3
# high_Re_small_nx_again_4
# high_Re_small_nx_again_5
# high_Re_small_nx_again_6
# high_Re_small_nx_again_7
# high_Re_small_nx_again_8
# high_Re_small_nx_again_9
# high_viscosity
# higher_re_maybe_good_mach_1
# higher_re_maybe_good_mach_2
# higher_re_maybe_good_mach_3
# higher_re_maybe_good_mach_4
# higher_re_maybe_good_mach_5
# higher_re_maybe_good_mach_6
# higher_visc_sampling_
# higher_visc_sampling_1
# higher_visc_sampling_10
# higher_visc_sampling_11
# higher_visc_sampling_12
# higher_visc_sampling_13
# higher_visc_sampling_14
# higher_visc_sampling_15
# higher_visc_sampling_16
# higher_visc_sampling_17
# higher_visc_sampling_2
# higher_visc_sampling_3
# higher_visc_sampling_4
# higher_visc_sampling_5
# higher_visc_sampling_6
# higher_visc_sampling_7
# higher_visc_sampling_8
# higher_visc_sampling_9
# hopefully_lower_variance_1
# hopefully_lower_variance_10
# hopefully_lower_variance_2
# hopefully_lower_variance_3
# hopefully_lower_variance_4
# hopefully_lower_variance_5
# hopefully_lower_variance_6
# hopefully_lower_variance_7
# hopefully_lower_variance_8
# hopefully_lower_variance_9
# large_forcing_small_on_perturb
# large_visc_sampling_sunday_1
# large_visc_sampling_sunday_10
# large_visc_sampling_sunday_11
# large_visc_sampling_sunday_12
# large_visc_sampling_sunday_13
# large_visc_sampling_sunday_14
# large_visc_sampling_sunday_15
# large_visc_sampling_sunday_16
# large_visc_sampling_sunday_17
# large_visc_sampling_sunday_18
# large_visc_sampling_sunday_19
# large_visc_sampling_sunday_2
# large_visc_sampling_sunday_20
# large_visc_sampling_sunday_21
# large_visc_sampling_sunday_22
# large_visc_sampling_sunday_3
# large_visc_sampling_sunday_4
# large_visc_sampling_sunday_5
# large_visc_sampling_sunday_6
# large_visc_sampling_sunday_7
# large_visc_sampling_sunday_8
# large_visc_sampling_sunday_9
# little_forcing
# low_perturb
# low_variance_higher_re_1
# low_variance_higher_re_2
# low_variance_higher_re_3
# lower_sampling_A_1
# lower_sampling_A_10
# lower_sampling_A_11
# lower_sampling_A_12
# lower_sampling_A_13
# lower_sampling_A_14
# lower_sampling_A_15
# lower_sampling_A_16
# lower_sampling_A_17
# lower_sampling_A_18
# lower_sampling_A_19
# lower_sampling_A_2
# lower_sampling_A_20
# lower_sampling_A_21
# lower_sampling_A_22
# lower_sampling_A_23
# lower_sampling_A_24
# lower_sampling_A_25
# lower_sampling_A_26
# lower_sampling_A_27
# lower_sampling_A_28
# lower_sampling_A_29
# lower_sampling_A_3
# lower_sampling_A_30
# lower_sampling_A_31
# lower_sampling_A_32
# lower_sampling_A_33
# lower_sampling_A_34
# lower_sampling_A_35
# lower_sampling_A_36
# lower_sampling_A_37
# lower_sampling_A_4
# lower_sampling_A_5
# lower_sampling_A_6
# lower_sampling_A_7
# lower_sampling_A_8
# lower_sampling_A_9
# more_forcing
# more_runs_A_12
# more_runs_A_2
# more_runs_A_26
# more_runs_A_29
# more_runs_A_3
# more_runs_A_30
# more_runs_B_1
# more_runs_B_10
# more_runs_B_11
# more_runs_B_12
# more_runs_B_13
# more_runs_B_14
# more_runs_B_15
# more_runs_B_16
# more_runs_B_17
# more_runs_B_18
# more_runs_B_19
# more_runs_B_2
# more_runs_B_20
# more_runs_B_21
# more_runs_B_22
# more_runs_B_23
# more_runs_B_24
# more_runs_B_25
# more_runs_B_26
# more_runs_B_27
# more_runs_B_28
# more_runs_B_29
# more_runs_B_3
# more_runs_B_30
# more_runs_B_4
# more_runs_B_5
# more_runs_B_6
# more_runs_B_7
# more_runs_B_8
# more_runs_B_9
# more_runs_C_1
# more_runs_C_10
# more_runs_C_11
# more_runs_C_12
# more_runs_C_13
# more_runs_C_14
# more_runs_C_15
# more_runs_C_16
# more_runs_C_17
# more_runs_C_18
# more_runs_C_19
# more_runs_C_2
# more_runs_C_20
# more_runs_C_21
# more_runs_C_22
# more_runs_C_23
# more_runs_C_24
# more_runs_C_25
# more_runs_C_26
# more_runs_C_27
# more_runs_C_28
# more_runs_C_29
# more_runs_C_3
# more_runs_C_30
# more_runs_C_4
# more_runs_C_5
# more_runs_C_6
# more_runs_C_7
# more_runs_C_8
# more_runs_C_9
# more_runs_D_1
# more_runs_D_10
# more_runs_D_11
# more_runs_D_12
# more_runs_D_13
# more_runs_D_14
# more_runs_D_15
# more_runs_D_16
# more_runs_D_17
# more_runs_D_18
# more_runs_D_19
# more_runs_D_2
# more_runs_D_20
# more_runs_D_21
# more_runs_D_22
# more_runs_D_23
# more_runs_D_24
# more_runs_D_25
# more_runs_D_26
# more_runs_D_27
# more_runs_D_28
# more_runs_D_29
# more_runs_D_3
# more_runs_D_30
# more_runs_D_4
# more_runs_D_5
# more_runs_D_6
# more_runs_D_7
# more_runs_D_8
# more_runs_D_9
# much_smaller_mach_hopefully_1
# much_smaller_mach_hopefully_2
# much_smaller_mach_hopefully_3
# much_smaller_mach_hopefully_4
# much_smaller_mach_hopefully_8
# much_smaller_mach_hopefully_9
# new_fast_runs_A_1
# new_fast_runs_A_10
# new_fast_runs_A_11
# new_fast_runs_A_12
# new_fast_runs_A_13
# new_fast_runs_A_14
# new_fast_runs_A_15
# new_fast_runs_A_16
# new_fast_runs_A_17
# new_fast_runs_A_18
# new_fast_runs_A_19
# new_fast_runs_A_2
# new_fast_runs_A_20
# new_fast_runs_A_21
# new_fast_runs_A_22
# new_fast_runs_A_23
# new_fast_runs_A_24
# new_fast_runs_A_25
# new_fast_runs_A_26
# new_fast_runs_A_27
# new_fast_runs_A_28
# new_fast_runs_A_29
# new_fast_runs_A_3
# new_fast_runs_A_30
# new_fast_runs_A_31
# new_fast_runs_A_32
# new_fast_runs_A_33
# new_fast_runs_A_34
# new_fast_runs_A_35
# new_fast_runs_A_36
# new_fast_runs_A_37
# new_fast_runs_A_38
# new_fast_runs_A_39
# new_fast_runs_A_4
# new_fast_runs_A_40
# new_fast_runs_A_41
# new_fast_runs_A_42
# new_fast_runs_A_43
# new_fast_runs_A_44
# new_fast_runs_A_45
# new_fast_runs_A_46
# new_fast_runs_A_47
# new_fast_runs_A_48
# new_fast_runs_A_49
# new_fast_runs_A_5
# new_fast_runs_A_50
# new_fast_runs_A_6
# new_fast_runs_A_7
# new_fast_runs_A_8
# new_fast_runs_A_9
# new_fast_runs_B_1
# new_fast_runs_B_10
# new_fast_runs_B_11
# new_fast_runs_B_12
# new_fast_runs_B_13
# new_fast_runs_B_14
# new_fast_runs_B_15
# new_fast_runs_B_16
# new_fast_runs_B_17
# new_fast_runs_B_18
# new_fast_runs_B_19
# new_fast_runs_B_2
# new_fast_runs_B_20
# new_fast_runs_B_21
# new_fast_runs_B_22
# new_fast_runs_B_23
# new_fast_runs_B_24
# new_fast_runs_B_25
# new_fast_runs_B_26
# new_fast_runs_B_27
# new_fast_runs_B_28
# new_fast_runs_B_29
# new_fast_runs_B_3
# new_fast_runs_B_30
# new_fast_runs_B_31
# new_fast_runs_B_32
# new_fast_runs_B_33
# new_fast_runs_B_34
# new_fast_runs_B_35
# new_fast_runs_B_36
# new_fast_runs_B_37
# new_fast_runs_B_38
# new_fast_runs_B_39
# new_fast_runs_B_4
# new_fast_runs_B_40
# new_fast_runs_B_41
# new_fast_runs_B_42
# new_fast_runs_B_43
# new_fast_runs_B_44
# new_fast_runs_B_45
# new_fast_runs_B_46
# new_fast_runs_B_47
# new_fast_runs_B_48
# new_fast_runs_B_49
# new_fast_runs_B_5
# new_fast_runs_B_50
# new_fast_runs_B_6
# new_fast_runs_B_7
# new_fast_runs_B_8
# new_fast_runs_B_9
# new_fast_runs_C_1
# new_fast_runs_C_10
# new_fast_runs_C_11
# new_fast_runs_C_12
# new_fast_runs_C_13
# new_fast_runs_C_14
# new_fast_runs_C_15
# new_fast_runs_C_16
# new_fast_runs_C_17
# new_fast_runs_C_18
# new_fast_runs_C_19
# new_fast_runs_C_2
# new_fast_runs_C_20
# new_fast_runs_C_21
# new_fast_runs_C_22
# new_fast_runs_C_23
# new_fast_runs_C_24
# new_fast_runs_C_25
# new_fast_runs_C_26
# new_fast_runs_C_27
# new_fast_runs_C_28
# new_fast_runs_C_29
# new_fast_runs_C_3
# new_fast_runs_C_30
# new_fast_runs_C_31
# new_fast_runs_C_32
# new_fast_runs_C_33
# new_fast_runs_C_34
# new_fast_runs_C_35
# new_fast_runs_C_36
# new_fast_runs_C_37
# new_fast_runs_C_38
# new_fast_runs_C_39
# new_fast_runs_C_4
# new_fast_runs_C_40
# new_fast_runs_C_41
# new_fast_runs_C_42
# new_fast_runs_C_43
# new_fast_runs_C_44
# new_fast_runs_C_45
# new_fast_runs_C_46
# new_fast_runs_C_47
# new_fast_runs_C_48
# new_fast_runs_C_49
# new_fast_runs_C_5
# new_fast_runs_C_50
# new_fast_runs_C_6
# new_fast_runs_C_7
# new_fast_runs_C_8
# new_fast_runs_C_9
# new_fast_runs_D_1
# new_fast_runs_D_10
# new_fast_runs_D_11
# new_fast_runs_D_12
# new_fast_runs_D_14
# new_fast_runs_D_15
# new_fast_runs_D_16
# new_fast_runs_D_17
# new_fast_runs_D_18
# new_fast_runs_D_19
# new_fast_runs_D_2
# new_fast_runs_D_20
# new_fast_runs_D_21
# new_fast_runs_D_22
# new_fast_runs_D_23
# new_fast_runs_D_3
# new_fast_runs_D_4
# new_fast_runs_D_47
# new_fast_runs_D_5
# new_fast_runs_D_6
# new_fast_runs_D_7
# new_fast_runs_D_8
# new_fast_runs_D_9
# new_hel_one_
# new_hel_one_1
# new_hel_one_10
# new_hel_one_11
# new_hel_one_12
# new_hel_one_13
# new_hel_one_14
# new_hel_one_15
# new_hel_one_16
# new_hel_one_17
# new_hel_one_18
# new_hel_one_2
# new_hel_one_3
# new_hel_one_4
# new_hel_one_5
# new_hel_one_6
# new_hel_one_7
# new_hel_one_8
# new_hel_one_9
# new_hel_zero_
# new_hel_zero_1
# new_hel_zero_10
# new_hel_zero_11
# new_hel_zero_12
# new_hel_zero_13
# new_hel_zero_14
# new_hel_zero_2
# new_hel_zero_3
# new_hel_zero_4
# new_hel_zero_5
# new_hel_zero_6
# new_hel_zero_7
# new_hel_zero_8
# new_hel_zero_9
# new_simuls_1
# new_simuls_2
# new_simuls_3
# new_simuls_4
# new_simuls_5
# new_simuls_6
# new_simuls_7
# old_wave_1
# old_wave_10
# old_wave_100
# old_wave_101
# old_wave_102
# old_wave_103
# old_wave_104
# old_wave_105
# old_wave_106
# old_wave_107
# old_wave_108
# old_wave_109
# old_wave_11
# old_wave_110
# old_wave_111
# old_wave_112
# old_wave_113
# old_wave_114
# old_wave_115
# old_wave_116
# old_wave_117
# old_wave_118
# old_wave_119
# old_wave_12
# old_wave_120
# old_wave_121
# old_wave_122
# old_wave_123
# old_wave_124
# old_wave_125
# old_wave_126
# old_wave_127
# old_wave_128
# old_wave_129
# old_wave_13
# old_wave_130
# old_wave_131
# old_wave_132
# old_wave_133
# old_wave_134
# old_wave_135
# old_wave_136
# old_wave_137
# old_wave_138
# old_wave_139
# old_wave_14
# old_wave_140
# old_wave_141
# old_wave_142
# old_wave_143
# old_wave_144
# old_wave_145
# old_wave_146
# old_wave_147
# old_wave_148
# old_wave_149
# old_wave_15
# old_wave_150
# old_wave_151
# old_wave_152
# old_wave_153
# old_wave_154
# old_wave_155
# old_wave_156
# old_wave_157
# old_wave_158
# old_wave_159
# old_wave_16
# old_wave_160
# old_wave_161
# old_wave_162
# old_wave_163
# old_wave_164
# old_wave_165
# old_wave_166
# old_wave_167
# old_wave_168
# old_wave_169
# old_wave_17
# old_wave_170
# old_wave_171
# old_wave_172
# old_wave_173
# old_wave_174
# old_wave_175
# old_wave_176
# old_wave_177
# old_wave_178
# old_wave_179
# old_wave_18
# old_wave_180
# old_wave_181
# old_wave_182
# old_wave_183
# old_wave_184
# old_wave_185
# old_wave_186
# old_wave_187
# old_wave_188
# old_wave_189
# old_wave_19
# old_wave_190
# old_wave_191
# old_wave_192
# old_wave_193
# old_wave_194
# old_wave_195
# old_wave_196
# old_wave_197
# old_wave_198
# old_wave_199
# old_wave_2
# old_wave_20
# old_wave_200
# old_wave_201
# old_wave_202
# old_wave_203
# old_wave_204
# old_wave_205
# old_wave_206
# old_wave_207
# old_wave_208
# old_wave_209
# old_wave_21
# old_wave_210
# old_wave_211
# old_wave_212
# old_wave_213
# old_wave_214
# old_wave_215
# old_wave_216
# old_wave_217
# old_wave_218
# old_wave_219
# old_wave_22
# old_wave_220
# old_wave_221
# old_wave_222
# old_wave_223
# old_wave_224
# old_wave_225
# old_wave_23
# old_wave_24
# old_wave_25
# old_wave_26
# old_wave_27
# old_wave_28
# old_wave_29
# old_wave_3
# old_wave_30
# old_wave_31
# old_wave_32
# old_wave_33
# old_wave_34
# old_wave_35
# old_wave_36
# old_wave_37
# old_wave_38
# old_wave_39
# old_wave_4
# old_wave_40
# old_wave_41
# old_wave_42
# old_wave_43
# old_wave_44
# old_wave_45
# old_wave_46
# old_wave_47
# old_wave_48
# old_wave_49
# old_wave_5
# old_wave_50
# old_wave_51
# old_wave_52
# old_wave_53
# old_wave_54
# old_wave_55
# old_wave_56
# old_wave_57
# old_wave_58
# old_wave_59
# old_wave_6
# old_wave_60
# old_wave_61
# old_wave_62
# old_wave_63
# old_wave_64
# old_wave_65
# old_wave_66
# old_wave_67
# old_wave_68
# old_wave_69
# old_wave_7
# old_wave_70
# old_wave_71
# old_wave_72
# old_wave_73
# old_wave_74
# old_wave_75
# old_wave_76
# old_wave_77
# old_wave_78
# old_wave_79
# old_wave_8
# old_wave_80
# old_wave_81
# old_wave_82
# old_wave_83
# old_wave_84
# old_wave_85
# old_wave_86
# old_wave_87
# old_wave_88
# old_wave_89
# old_wave_9
# old_wave_90
# old_wave_91
# old_wave_92
# old_wave_93
# old_wave_94
# old_wave_95
# old_wave_96
# old_wave_97
# old_wave_98
# old_wave_99
# old_wave_new_params_1
# old_wave_new_params_2
# old_wave_new_params_3
# old_wave_new_params_4
# old_wave_new_params_5
# old_wave_new_params_6
# same_params_1
# same_params_2
# same_params_3
# same_params_4
# same_params_long_baserun_1
# same_params_long_baserun_2
# same_params_long_final_1
# same_params_long_final_10
# same_params_long_final_11
# same_params_long_final_12
# same_params_long_final_13
# same_params_long_final_14
# same_params_long_final_15
# same_params_long_final_16
# same_params_long_final_17
# same_params_long_final_18
# same_params_long_final_19
# same_params_long_final_2
# same_params_long_final_20
# same_params_long_final_21
# same_params_long_final_22
# same_params_long_final_23
# same_params_long_final_24
# same_params_long_final_25
# same_params_long_final_26
# same_params_long_final_27
# same_params_long_final_28
# same_params_long_final_29
# same_params_long_final_3
# same_params_long_final_30
# same_params_long_final_31
# same_params_long_final_32
# same_params_long_final_33
# same_params_long_final_34
# same_params_long_final_35
# same_params_long_final_36
# same_params_long_final_37
# same_params_long_final_38
# same_params_long_final_39
# same_params_long_final_4
# same_params_long_final_40
# same_params_long_final_41
# same_params_long_final_42
# same_params_long_final_43
# same_params_long_final_44
# same_params_long_final_45
# same_params_long_final_46
# same_params_long_final_47
# same_params_long_final_48
# same_params_long_final_49
# same_params_long_final_5
# same_params_long_final_50
# same_params_long_final_6
# same_params_long_final_7
# same_params_long_final_8
# same_params_long_final_9
# same_params_short_final_1
# same_params_short_final_10
# same_params_short_final_11
# same_params_short_final_12
# same_params_short_final_13
# same_params_short_final_14
# same_params_short_final_15
# same_params_short_final_16
# same_params_short_final_17
# same_params_short_final_18
# same_params_short_final_19
# same_params_short_final_20
# same_params_short_final_21
# same_params_short_final_22
# same_params_short_final_23
# same_params_short_final_24
# same_params_short_final_25
# same_params_short_final_26
# same_params_short_final_27
# same_params_short_final_28
# same_params_short_final_29
# same_params_short_final_3
# same_params_short_final_30
# same_params_short_final_4
# same_params_short_final_5
# same_params_short_final_7
# same_params_short_final_8
# same_params_short_final_9
# sample_0
# sample_1
# sample_10
# sample_11
# sample_12
# sample_13
# sample_14
# sample_15
# sample_16
# sample_17
# sample_18
# sample_2
# sample_21
# sample_22
# sample_23
# sample_24
# sample_25
# sample_26
# sample_27
# sample_28
# sample_29
# sample_3
# sample_30
# sample_31
# sample_32
# sample_33
# sample_34
# sample_35
# sample_36
# sample_37
# sample_38
# sample_39
# sample_4
# sample_40
# sample_41
# sample_42
# sample_43
# sample_44
# sample_45
# sample_46
# sample_47
# sample_48
# sample_49
# sample_5
# sample_50
# sample_51
# sample_52
# sample_53
# sample_54
# sample_55
# sample_56
# sample_57
# sample_58
# sample_59
# sample_6
# sample_60
# sample_61
# sample_62
# sample_63
# sample_64
# sample_65
# sample_66
# sample_67
# sample_68
# sample_69
# sample_7
# sample_70
# sample_71
# sample_72
# sample_73
# sample_74
# sample_75
# sample_76
# sample_77
# sample_78
# sample_79
# sample_8
# sample_80
# sample_81
# sample_82
# sample_space_1
# sample_space_2
# sample_space_3
# sample_space_4
# sample_space_5
# sample_space_6
# sample_space_7
# sample_space_8
# small_nx_better_mach_maybe_1
# small_nx_better_mach_maybe_10
# small_nx_better_mach_maybe_11
# small_nx_better_mach_maybe_12
# small_nx_better_mach_maybe_13
# small_nx_better_mach_maybe_14
# small_nx_better_mach_maybe_15
# small_nx_better_mach_maybe_16
# small_nx_better_mach_maybe_17
# small_nx_better_mach_maybe_18
# small_nx_better_mach_maybe_19
# small_nx_better_mach_maybe_2
# small_nx_better_mach_maybe_20
# small_nx_better_mach_maybe_21
# small_nx_better_mach_maybe_22
# small_nx_better_mach_maybe_23
# small_nx_better_mach_maybe_24
# small_nx_better_mach_maybe_25
# small_nx_better_mach_maybe_26
# small_nx_better_mach_maybe_27
# small_nx_better_mach_maybe_28
# small_nx_better_mach_maybe_29
# small_nx_better_mach_maybe_3
# small_nx_better_mach_maybe_30
# small_nx_better_mach_maybe_4
# small_nx_better_mach_maybe_5
# small_nx_better_mach_maybe_6
# small_nx_better_mach_maybe_7
# small_nx_better_mach_maybe_8
# small_nx_better_mach_maybe_9
# test
# test_1
# test_2
# tests_with_timesteps_1
# tests_with_timesteps_2
# tests_with_timesteps_3
# tests_with_timesteps_4
# tiny_forcing
# tiny_forcing_new
# tiny_forcing_repeat
# ts_reader_crash_18
# with_error_handling_1
# with_error_handling_10
# with_error_handling_11
# with_error_handling_12
# with_error_handling_13
# with_error_handling_14
# with_error_handling_15
# with_error_handling_16
# with_error_handling_17
# with_error_handling_18
# with_error_handling_19
# with_error_handling_2
# with_error_handling_20
# with_error_handling_21
# with_error_handling_3
# with_error_handling_4
# with_error_handling_5
# with_error_handling_6
# with_error_handling_7
# with_error_handling_8
# with_error_handling_9

# %%
interesting_dirs = ["tiny_forcing_repeat"] + ["new_simuls_"+str(i) for i in range(1,7+1)] #nothing
chaotic_dirs = ["tiny_forcing_repeat"] + ["new_simuls_" + str(i) for i in [4,5,6,7]] #nothing
same_param_dirs = ["same_params_"+str(i) for i in [1,3,4]] #nothing
same_param_long_baserun_dirs = ["same_params_long_baserun_"+str(i) for i in [1,2]] #nothing
test_dirs = ["test"] # nothing
different_params_long_baserun = ["different_params_long_final_" + str(i) for i in range(1,10)] # what a failure

hopefully_lower_variance = ["hopefully_lower_variance_" + str(i) for i in range(1,10)] # Re too low


low_variance_higher_re = ["low_variance_higher_re_" + str(i) for i in range(1,3)]

new_runs = ["same_params_short_final_"+str(i) for i in range(1,31)] # also something
long_final = ["same_params_long_final_"+str(i) for i in range(1,46)] # those work
high_Re_small_nx_again = ["high_Re_small_nx_again_"+str(i) for i in range(1,31)] #mach number is high
small_nx_better_mach_maybe = ["small_nx_better_mach_maybe_"+str(i) for i in range(1,31)] #mach number is high
much_smaller_mach_hopefully = ["much_smaller_mach_hopefully_"+str(i) for i in range(1,5)] # this is supersonic!!

even_more_test_runs = ["even_more_tests_"+str(i) for i in range(5)]

more_runs_A = ["more_runs_A_"+str(i) for i in range(51)] # only one succesful run????
more_runs_B = ["more_runs_B_"+str(i) for i in range(51)] # not turbulent
more_runs_C = ["more_runs_C_"+str(i) for i in range(51)] # merkwürdig linear
more_runs_D = ["more_runs_D_"+str(i) for i in range(51)] # nicht turbulent

new_fast_runs_A = ["new_fast_runs_A_"+str(i) for i in range(51)] # sieht besser aus
new_fast_runs_B = ["new_fast_runs_B_"+str(i) for i in range(51)] # nicht turbulent
new_fast_runs_C = ["new_fast_runs_C_"+str(i) for i in range(51)] # sieht gut aus
new_fast_runs_D = ["new_fast_runs_D_"+str(i) for i in range(51)] # merkwürdig linear

lower_sampling_A = ["lower_sampling_A_"+str(i) for i in range(41)]
lower_sampling_B = ["lower_sampling_B_"+str(i) for i in range(41)]
lower_sampling_C = ["lower_sampling_C_"+str(i) for i in range(41)]
lower_sampling_D = ["lower_sampling_D_"+str(i) for i in range(41)]

sample = ["sample_"+str(i) for i in range(1000)]

old_wave = ["old_wave_"+str(i) for i in range(300)]
old_wave_new_params = ["old_wave_new_params_"+str(i) for i in range(300)]
high_visc_sampling = ["higher_visc_sampling_"+str(i)  for i in range(500)]
large_visc = ["large_visc_"+str(i) for i in range(100)]
large_visc_sampling_sunday = ["large_visc_sampling_sunday_"+str(i) for i in range(200)]

detailed_A = ["detailed_A_" + str(i) for i in range(100)] # nice growth
detailed_B = ["detailed_B_" + str(i) for i in range(100)] # decrease
detailed_C = ["detailed_C_" + str(i) for i in range(100)] # growth yes, but somehow some simuls failed
detailed_D = ["detailed_D_" + str(i) for i in range(100)] # decrease
detailed_E = ["detailed_E_" + str(i) for i in range(100)] # decrease than increase, how to handle?
detailed_F = ["detailed_F_" + str(i) for i in range(100)] # sieht gut aus, aber mach sehr hoch

force13_A = ["force13_A_" + str(i) for i in range(200)] # decrease
force13_B = ["force13_B_" + str(i) for i in range(200)] # dip
force13_C = ["force13_C_" + str(i) for i in range(200)] # decrease

hel_one = ["hel_one_" + str(i) for i in range(200)] # dip
hel_half = ["hel_half_" + str(i) for i in range(200)] # also a dip

hel_one = ["hel_one_" + str(i) for i in range(200)] # dip
hel_half = ["hel_half_" + str(i) for i in range(200)] # also a dip

hel_one_higher_force = ["hel_one_higher_force_" + str(i) for i in range(200)]
hel_half_higher_force = ["hel_half_higher_force_" + str(i) for i in range(200)]
hel_zero_higher_force = ["hel_zero_higher_force_" + str(i) for i in range(200)]

new_hel_one = ["new_hel_one_" + str(i) for i in range(200)]
new_hel_half = ["new_hel_half_" + str(i) for i in range(200)]
new_hel_zero = ["new_hel_zero_" + str(i) for i in range(200)]

# %%
def filter_successful(simuls):
    return list(filter(lambda d : os.path.isfile(d+"/results.csv"), simuls))
filter_successful(new_hel_half)
# Out:
# []

# %%
all_simuls = [*more_runs_A, *more_runs_B, *more_runs_C, *more_runs_D,
              *new_fast_runs_A, *new_fast_runs_B, *new_fast_runs_C, *new_fast_runs_D,
             *lower_sampling_A , *lower_sampling_B , *lower_sampling_C , *lower_sampling_D,
              *sample, *old_wave, *old_wave_new_params, *high_visc_sampling, *large_visc, *large_visc_sampling_sunday]
all_simuls = filter_successful(all_simuls)
print(len(all_simuls))
# Out:
# 595

# %%
# map physical input parameters to measured parameters

ins = ["viscosity", "forcing_magnitude", "relhel"]
out_names =  ["mach", "Re", "Re_mesh"]
outs = collections.defaultdict(lambda : {k:[] for k in out_names})


oldkey = None
for s in all_simuls:
    
    key = ()
    with open(s+"/core_options.json", "r") as f:
        opts = json.load(f)
        for k,v in opts.items():
            if k in ins:
                key = key + (v,)
    #print(key) if key != oldkey else print(".", end="")
    oldkey = key
    vals = {"mach":[], "Re": [], "Re_mesh": []}
    with open(s+"/results.csv", "r") as f:
        
        r = csv.DictReader(f)
        for row in r:
            for k,v in row.items():
                if k in out_names:
                    vals[k].append(float(v))
        # correct Re_mesh:
        for i in range(len(vals["Re_mesh"])):
            vals["Re_mesh"][i] = vals["Re"][i]*opts["dsx"]
            
    for o in out_names:
        outs[key][o].append(stat.mean(vals[o]))
        
p2mach = {p:stat.mean(v["mach"]) for p,v in outs.items()}
p2Re = {p:stat.mean(v["Re"]) for p,v in outs.items()}
p2Re_mesh = {p:stat.mean(v["Re_mesh"]) for p,v in outs.items()}
viscs = list(map(lambda x: x[0], p2mach.keys()))
forc = list(map(lambda x: x[1], p2mach.keys()))

# %%
def color_points(vals, title, marks):
    
    print(list(zip(*marks)))
    vmarks, fmarks, syms = marks
    vmin, vmax = np.quantile(vals, (0.1,0.9))
    plt.scatter(viscs, forc, c=vals,vmin=vmin, vmax=vmax, cmap="rainbow")
    plt.colorbar()
    for v,f,sym in zip(*marks):
        plt.scatter(v, f, marker="x", label=sym)
    plt.ylabel("forcing")
    plt.xlabel("visc")
    plt.legend()
    plt.title(title)
    plt.show()
    
def as_array(data):
    vals = np.array(list(map(float, data.values())))
    return vals

mach_arr = as_array(p2mach)
re_arr = as_array(p2Re)
re_mesh_arr = as_array(p2Re_mesh)
vmarks = [0.0009, 0.01, 0.0005, 0.02, 0.005, 0.005, 0.002]
fmarks = [0.06, 0.15, 0.10, 0.025, 0.125, 0.16, 0.125]
syms = ["A", "B", "C", "D", "E", "F","G"]
marks = (vmarks, fmarks, syms)
color_points(mach_arr, "mach", marks)
color_points(re_arr, "Re", marks)
color_points(re_mesh_arr, "Re_mesh", marks)
# Out:
# [(0.0009, 0.06, 'A'), (0.01, 0.15, 'B'), (0.0005, 0.1, 'C'), (0.02, 0.025, 'D'), (0.005, 0.125, 'E'), (0.005, 0.16, 'F'), (0.002, 0.125, 'G')]
# [(0.0009, 0.06, 'A'), (0.01, 0.15, 'B'), (0.0005, 0.1, 'C'), (0.02, 0.025, 'D'), (0.005, 0.125, 'E'), (0.005, 0.16, 'F'), (0.002, 0.125, 'G')]
# [(0.0009, 0.06, 'A'), (0.01, 0.15, 'B'), (0.0005, 0.1, 'C'), (0.02, 0.025, 'D'), (0.005, 0.125, 'E'), (0.005, 0.16, 'F'), (0.002, 0.125, 'G')]

# %%
#when the mesh reynolds number is lower than 1, it is inefficient but accurate, large is worse
#mach number: cannot do more than 0.5, because we dont have shock viscosity, maybe fine if no crashes and we dont see artifacts
    #maybe orange is still safe

# %%
#################
#################
active_simuls = detailed_E
#################
#################

            
active_simuls = list(filter(lambda d : os.path.isfile(d+"/results.csv"), active_simuls))

# check validity -> seems silly now that I filter all the failed runs automatically
for d in active_simuls:
    
    if not os.path.isfile(d+"/results.csv"):
        print(d , " does not have results")

print(active_simuls)
print(len(active_simuls))
# Out:
# ['detailed_E_1', 'detailed_E_2', 'detailed_E_3', 'detailed_E_4', 'detailed_E_5', 'detailed_E_6', 'detailed_E_7', 'detailed_E_8', 'detailed_E_9', 'detailed_E_10']
# 10

# %%
res = {}
opts = {}

param_space = [] # tuples: (dirname, Re, mach, hel)

mach_numbers = []
Re_numbers = []

for dirname in active_simuls:
    
    results = collections.defaultdict(list)
    with open(dirname+"/results.csv", "r") as f:
        reader = csv.DictReader(f)
        print(reader.fieldnames)
        for row in reader:
            for k,v in row.items():
                results[k].append(float(v))
    res[dirname] = {k: np.array(v) for k,v in results.items()}            
    
    mach_mean = np.mean(res[dirname]["mach"])
    mesh_Re_mean = np.mean(res[dirname]["Re_mesh"])
    urms_mean = np.mean(res[dirname]["urms"])
    Re_mean = np.mean(res[dirname]["Re"])
    print(res[dirname]["real_time"])
    
    
    print("DIRECTORY: ", dirname)
    print("mach:", mach_mean)
    print("mesh_Re: ", mesh_Re_mean)
    print("urms: ", urms_mean)
    print("Re: ", Re_mean)
    
    with open(dirname+"/core_options.json", "r") as f:
        opts[dirname] = json.load(f)
        print(opts[dirname])
    

    param_space.append((dirname, Re_mean, mach_mean, opts[dirname]["relhel"]))
    mach_numbers.append(mach_mean)
    Re_numbers.append(Re_mean)
    
    plt.plot(res[dirname]["real_time"],res[dirname]["var"])
    relhel = opts[dirname]["relhel"]
    plt.title(f"Re={Re_mean} || forcing_helicity={relhel}")
    #plt.yscale("log")
    plt.show()
    print(("="*10+"\n")*3)
# Out:
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [107.57704923 107.6276779  107.69091982 107.75459576 107.8185576
#  107.88245301 107.94627278 108.01020139 108.07422993 108.13849795
#  108.20283125 108.26709332 108.33140492]
# DIRECTORY:  detailed_E_1
# mach: 0.5342440513464121
# mesh_Re:  1.3152232079917288
# urms:  0.13396753588548074
# Re:  26.793507177096146
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [107.95684804 108.00912706 108.07491113 108.14092905 108.20675477
#  108.27214936 108.33754483 108.4032154  108.46897697 108.53474698
#  108.60049563 108.6668061  108.73307328]
# DIRECTORY:  detailed_E_2
# mach: 0.49660394111504924
# mesh_Re:  1.2465640805294127
# urms:  0.12697397459011814
# Re:  25.394794918023624
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [111.11660404 111.17098232 111.23895002 111.30702549 111.37539236
#  111.444148   111.51308793 111.58208102 111.65103584 111.72012746
#  111.78972488 111.8594735  111.92955233]
# DIRECTORY:  detailed_E_3
# mach: 0.42086249108497914
# mesh_Re:  1.233487278913851
# urms:  0.12564198251527087
# Re:  25.12839650305418
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [108.37624131 108.43064404 108.49880368 108.56737168 108.63594972
#  108.70423433 108.77223752 108.83988489 108.90733454 108.97417698
#  109.04099979 109.10793345 109.17473954]
# DIRECTORY:  detailed_E_4
# mach: 0.4550312751760849
# mesh_Re:  1.2714690854305257
# urms:  0.12951077755827173
# Re:  25.90215551165434
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [104.56615793 104.61498514 104.67610202 104.73710022 104.79824118
#  104.8591884  104.92015125 104.98119635 105.04192899 105.10258827
#  105.16292114 105.22315161 105.28305655]
# DIRECTORY:  detailed_E_5
# mach: 0.615816300878158
# mesh_Re:  1.6356500496316708
# urms:  0.16660594596312597
# Re:  33.32118919262519
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [110.98738672 111.04156551 111.10923702 111.17704222 111.24458236
#  111.31232143 111.38020345 111.44827502 111.51658912 111.5847938
#  111.65291552 111.72088751 111.78900813]
# DIRECTORY:  detailed_E_6
# mach: 0.4463345560889978
# mesh_Re:  1.1089109636564365
# urms:  0.11295274324142013
# Re:  22.59054864828403
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [113.30796535 113.35849553 113.4222197  113.48613765 113.54996996
#  113.61370184 113.6772581  113.7407381  113.8038589  113.86710005
#  113.93053605 113.99381514 114.05679034]
# DIRECTORY:  detailed_E_7
# mach: 0.5511056331487801
# mesh_Re:  1.3816079935449492
# urms:  0.14072943461629062
# Re:  28.14588692325812
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [113.1902719  113.24766846 113.31947078 113.39098979 113.46300386
#  113.53496546 113.60699    113.67893502 113.75123198 113.8237794
#  113.89683265 113.9700375  114.04334974]
# DIRECTORY:  detailed_E_8
# mach: 0.3598207917350989
# mesh_Re:  0.9635968849307915
# urms:  0.09815117272620019
# Re:  19.630234545240036
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [104.19137579 104.24420376 104.31010526 104.37562992 104.44093409
#  104.50612185 104.57117939 104.63603466 104.70120151 104.76633997
#  104.83193029 104.89777149 104.96330712]
# DIRECTORY:  detailed_E_9
# mach: 0.5007882595062256
# mesh_Re:  1.3455921398983224
# urms:  0.13706088988826823
# Re:  27.41217797765365
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========
#
# ['urms', 'urms_var', 'mach', 'mach_var', 'Re', 'Re_var', 'Re_mesh', 'Re_mesh_var', 'var', 'real_time', 'timestep']
# [114.27636826 114.33021605 114.39791309 114.46595067 114.53369948
#  114.60133884 114.6692163  114.73706113 114.80504256 114.87324907
#  114.94116216 115.00906813 115.07693719]
# DIRECTORY:  detailed_E_10
# mach: 0.44464664401916354
# mesh_Re:  1.2231443659449552
# urms:  0.12458846205129072
# Re:  24.917692410258148
# {'save_steps': 25, 'viscosity': 0.005, 'forcing_magnitude': 0.125, 'relhel': 1.0, 'forcing_kmin': 0.8, 'forcing_kmax': 1.2, 'nx': 128, 'ny': 128, 'nz': 128, 'dsx': 0.04908738521234052, 'dsy': 0.04908738521234052, 'dsz': 0.04908738521234052}
# ==========
# ==========
# ==========

# %%
mach_mean = stat.mean(mach_numbers)
mach_var = np.sqrt(stat.variance(mach_numbers))
Re_mean = stat.mean(Re_numbers)
Re_var = np.sqrt(stat.variance(Re_numbers))

print(mach_mean)
print(mach_var)
print(Re_mean)
print(Re_var)

plt.scatter(mach_numbers, Re_numbers)
plt.errorbar([mach_mean], [Re_mean], xerr=mach_var, yerr=Re_var, color="black")
plt.xlabel("mach")
plt.ylabel("Re")
plt.show()
# Out:
# 0.48252539440989495
# 0.07305668145944395
# 25.92365838071475
# 3.578880354278511

# %%
Re2simul = dict(sorted(
    {np.mean(res[c]["Re"]) : {**res[c], "dir": c} for c in active_simuls}.items()))

# lists are ordered, sets arent
active_list = list(active_simuls)
Re_list = [np.mean(res[c]["Re"]) for c in active_list]
relvar = [res[c]["var"]/res[c]["var"][0] for c in active_list]
#logrelvar = [np.log(res[c]["welf_var"]/res[c]["welf_var"][0]) for c in active_list]
time_elapsed = [res[c]["real_time"] - res[c]["real_time"][0] for c in active_list]

def all_the_same(ls):
    return all(x==ls[0] for x in ls)
assert(all_the_same(list((map(len,[active_list, Re_list, relvar, time_elapsed])))))

# %%
# relative increase after n timesteps 
# (this is not a proper definition for growth, but ok to get an idea)
rand_color = np.random.rand(len(Re2simul),3)*0.5
for n in range(1,len(relvar[0])):
    Re, rel_increase = list(zip(*[(Re , res["var"][n]/res["var"][0]) for Re, res in Re2simul.items()]))
    rel_increase = np.log(rel_increase)
    
    linres = scipy.stats.linregress(Re,rel_increase)
    Abest, bbest = linres.slope, linres.intercept
    print("A",round(Abest,6))
    print("b", round(bbest,5))
    
    xline = np.linspace(min(Re)*0.95, max(Re)*1.05)
    plt.plot(xline, (lambda x: Abest*x+bbest)(xline))
    plt.scatter(Re, rel_increase, c=rand_color)
    plt.title(f"timesteps since perturbation: {n}")
    plt.ylabel("relative increase since perturbation")
    plt.xlabel("Re")
    plt.show()
    sleep(0.1) # commented out for when I rerun the notebook
    clear_output(wait=True)
# Out:
# A 0.000355
# b -0.01113

# %%
def normalize(data):
    return data/data[0]

def adjust(data):
    ln = np.log
    #return ln(data/data[0])
    #return ln(ln(data/data[0]) + 1) # still nonlinear growth
    #return ln(ln(ln(data/data[0]) + 1) + 1) # still nonlinear
    return ln(ln(ln(ln(data/data[0]) + 1) + 1) + 1) # still nonlinear


for mi in [5,10,20]:
    for Re, r in list(Re2simul.items())[::]:
        relhel = opts[r["dir"]]["relhel"]
        urms = np.mean(r["urms"])
        #plt.plot(r["time"], r["urms"])
        plt.plot(r["real_time"][:mi] - r["real_time"][0], adjust(r["var"])[:mi], label=f"Re={round(Re,2)}, urms={round(urms, 3)}")

    x = linspace(0,1.4,20)
    

    #plt.xlim(0.0,0.4)
    #plt.ylim(0.999, 1.015)
    #plt.yscale("log")
    plt.title(f"mi={mi}")
    plt.legend()
    plt.show()

# %%
# fit through data
# model var(t)=b*t**a -> ln(var) = ln(b) + a*ln(t)
# so we find a and b by linear regression

@dataclass
class Fitres():
    a: float
    b: float
    rsq: float
    a_err : float
    simul_name : str
    
    def __call__(self, t):
        return self.b*t**self.a
        
    
simul2fit = {}

show = True
for simul, Re, var, t in zip(active_list, Re_list, relvar, time_elapsed):
    
    # only use the first values (or cutoff==None for use all)
    #cutoff = None
    cutoff = None
    e = cutoff
    
    # this ignores values that cant be put in log, not really the right way to go
    valid = (var[1:e] > 1)
    
    print(f"datapoints: {len(valid)} out of {len(var)} available")
    
    
    lnt = ln(t[1:e][valid])
    lnvar = ln(var[1:e][valid] -1)
    
    assert(np.all(~np.isnan(lnt)))
    assert(np.all(~np.isnan(lnvar)))
    
    
    linres = scipy.stats.linregress(lnt,lnvar)
    a, lnb = linres.slope, linres.intercept
    a_err = linres.stderr
    b = exp(lnb)
    rsq = linres.rvalue**2
    fitres = Fitres(a,b,rsq,a_err, simul)
    if show:
        print(simul)
        print(fitres)
        plt.plot(lnt, lnvar, label="data")
        plt.plot(lnt, lnb+ a*lnt, linestyle="--", label="fit")
        #plt.plot(lnt, ln(fitres(t[1:e][valid])), label="log of fitres")
        plt.legend()
        plt.show()
        
        plt.plot(t, var, label="measured")
        plt.plot(t, fitres(t)+1, linestyle="--", label="fit")
        plt.legend()
        plt.show()
        print("============")
    
    assert(fitres.simul_name == simul)
    simul2fit[simul] = fitres
# Out:
# datapoints: 12 out of 13 available
# detailed_A_1
# Fitres(a=2.127701994696875, b=0.0478292862612457, rsq=0.9976073374964611, a_err=0.03295123566236884, simul_name='detailed_A_1')
# ============
# datapoints: 12 out of 13 available
# detailed_A_2
# Fitres(a=2.113459606804639, b=0.05126352789552712, rsq=0.9981227472030217, a_err=0.028984335976900373, simul_name='detailed_A_2')
# ============
# datapoints: 12 out of 13 available
# detailed_A_3
# Fitres(a=2.1942262706697058, b=0.03863619231128911, rsq=0.9958032214000331, a_err=0.04504563114738059, simul_name='detailed_A_3')
# ============
# datapoints: 12 out of 13 available
# detailed_A_4
# Fitres(a=2.3481715247295036, b=0.0316895243494823, rsq=0.9890766933163799, a_err=0.07803544237405999, simul_name='detailed_A_4')
# ============
# datapoints: 12 out of 13 available
# detailed_A_5
# Fitres(a=2.092783149052995, b=0.060435906812499295, rsq=0.9985350344456004, a_err=0.025348734511163946, simul_name='detailed_A_5')
# ============
# datapoints: 12 out of 13 available
# detailed_A_6
# Fitres(a=2.6449291415783365, b=0.036642407740356715, rsq=0.9645003134612892, a_err=0.1604630763908875, simul_name='detailed_A_6')
# ============
# datapoints: 12 out of 13 available
# detailed_A_7
# Fitres(a=2.3567918762238014, b=0.027150922499865515, rsq=0.9869775963202961, a_err=0.08560776563999979, simul_name='detailed_A_7')
# ============
# datapoints: 12 out of 13 available
# detailed_A_8
# Fitres(a=2.2093810640192486, b=0.012988826408820424, rsq=0.9954865487959567, a_err=0.04958907992452341, simul_name='detailed_A_8')
# ============
# datapoints: 12 out of 13 available
# detailed_A_9
# Fitres(a=2.221566884285354, b=0.0420633090500304, rsq=0.9948726675046812, a_err=0.050433764236052385, simul_name='detailed_A_9')
# ============
# datapoints: 12 out of 13 available
# detailed_A_10
# Fitres(a=2.199352905349572, b=0.025655235367242693, rsq=0.9960028952434846, a_err=0.04644255791647669, simul_name='detailed_A_10')
# ============
# datapoints: 12 out of 13 available
# detailed_A_12
# Fitres(a=2.2114971825157115, b=0.034888594226103097, rsq=0.9950042507304224, a_err=0.04955348912586527, simul_name='detailed_A_12')
# ============
# datapoints: 12 out of 13 available
# detailed_A_13
# Fitres(a=2.1869922283081578, b=0.017326825960305436, rsq=0.9961708366964013, a_err=0.045197146574063755, simul_name='detailed_A_13')
# ============
# datapoints: 12 out of 13 available
# detailed_A_14
# Fitres(a=2.2818235754287386, b=0.03642805386445007, rsq=0.9913672171405226, a_err=0.06733489617149013, simul_name='detailed_A_14')
# ============
# datapoints: 12 out of 13 available
# detailed_A_15
# Fitres(a=2.5503922829340455, b=0.02753846943153, rsq=0.9727075125034284, a_err=0.13509441984038653, simul_name='detailed_A_15')
# ============
# datapoints: 12 out of 13 available
# detailed_A_16
# Fitres(a=2.144029018597393, b=0.05103017102675915, rsq=0.9971069845516639, a_err=0.03652036893682514, simul_name='detailed_A_16')
# ============
# datapoints: 12 out of 13 available
# detailed_A_17
# Fitres(a=2.121490463198675, b=0.04872455293199676, rsq=0.9978355789168886, a_err=0.031245139576870598, simul_name='detailed_A_17')
# ============
# datapoints: 12 out of 13 available
# detailed_A_18
# Fitres(a=2.224656566903077, b=0.04362838773940711, rsq=0.9943516992068652, a_err=0.05302148341119084, simul_name='detailed_A_18')
# ============
# datapoints: 12 out of 13 available
# detailed_A_19
# Fitres(a=2.1246507759633344, b=0.04944795745137728, rsq=0.997877839988478, a_err=0.03098403185446456, simul_name='detailed_A_19')
# ============
# datapoints: 12 out of 13 available
# detailed_A_20
# Fitres(a=2.128379597789045, b=0.051919010710579756, rsq=0.9976200128876828, a_err=0.03287409557899893, simul_name='detailed_A_20')
# ============

# %%
# visual checks on quality of fit

for simul, fitfun in list(simul2fit.items())[::5]:
    
    
    print("======================")
    assert(simul==fitfun.simul_name)
    print(simul)
    print(fitfun)
    
    # normalize and set to time since zero, otherwise no point
    t = res[simul]["real_time"] - res[simul]["real_time"][0]
    var = res[simul]["var"]/res[simul]["var"][0] -1
    
    plt.plot(ln(t[1:]), ln(var[1:] + 1), label="measured")
    plt.plot(ln(t[1:]), ln(fitfun(t[1:])+1), linestyle="--",  label="fit")
    plt.legend()
    plt.show()
    
    plt.plot(t,var, label="measured")
    plt.plot(t,fitfun(t), label="fit")
    plt.legend()
    plt.show()
    
    
# it seems like the slope of the (logarithmic) data decreases with time, so a single exponential is maybe not accurate
# Out:
# ======================
# detailed_A_1
# Fitres(a=2.127701994696875, b=0.0478292862612457, rsq=0.9976073374964611, a_err=0.03295123566236884, simul_name='detailed_A_1')
# ======================
# detailed_A_6
# Fitres(a=2.6449291415783365, b=0.036642407740356715, rsq=0.9645003134612892, a_err=0.1604630763908875, simul_name='detailed_A_6')
# ======================
# detailed_A_12
# Fitres(a=2.2114971825157115, b=0.034888594226103097, rsq=0.9950042507304224, a_err=0.04955348912586527, simul_name='detailed_A_12')
# ======================
# detailed_A_17
# Fitres(a=2.121490463198675, b=0.04872455293199676, rsq=0.9978355789168886, a_err=0.031245139576870598, simul_name='detailed_A_17')

# %%
slope_vals = [fitres.a for _,fitres in simul2fit.items()]
intercept_vals = [fitres.b for _,fitres in simul2fit.items()]

# powerlaw fit through data assuming eq16 from Petry where c0 is const and sigma_half is a number
# lambda = c0*Re^sigma -> ln(lambda) = lnc0 + sigma*ln(Re)
valid_Re = np.array(Re_list)[~np.isnan(slope_vals)]
valid_slopes = np.array(slope_vals)[~np.isnan(slope_vals)]
fit = scipy.stats.linregress(ln(valid_Re), ln(valid_slopes))
sigma, lnc0 = fit.slope, fit.intercept
print(sigma, lnc0)
c0 = np.exp(lnc0)
Re_range = np.linspace(min(valid_Re), max(valid_Re), 100)


rand_color = np.random.rand(len(Re2simul),3)
plt.scatter(Re_list, slope_vals, c=rand_color)
plt.plot(Re_range, c0*Re_range**sigma, label="fit")
plt.ylabel("a in function   $b\cdot t^a$")
plt.xlabel("Re")
plt.legend()
plt.show()

plt.scatter(Re_list, intercept_vals, c=rand_color)
plt.ylabel("b in function   $b\cdot t^a$")
plt.xlabel("Re")
plt.show()
# Out:
# -0.31706246082634526 2.251891921911919

# %%
# bin by Re, then calculate an average for each bin
bins = list(range(70,150,5))
for i in range(len(bins)-1):
    low = bins[i]
    hi = bins[i+1]
    center = (low+hi)/2
    slopes = valid_slopes[np.logical_and(low <= valid_Re,valid_Re < hi)]
    print(center, len(slopes), round(np.mean(slopes),3) if len(slopes) > 0 else "-")
# Out:
# 72.5 0 -
# 77.5 0 -
# 82.5 2 2.279
# 87.5 1 2.55
# 92.5 6 2.277
# 97.5 4 2.182
# 102.5 1 2.225
# 107.5 3 2.145
# 112.5 1 2.199
# 117.5 1 2.128
# 122.5 0 -
# 127.5 0 -
# 132.5 0 -
# 137.5 0 -
# 142.5 0 -

# %%
print("Re: ", np.mean(valid_Re))
print("slope: ",np.mean(valid_slopes))

# %%
x = linspace(0,3,100)
y = exp(-x)
plt.plot(x,y)
plt.yscale("log")
plt.show()

# %%
y = x**2.5
normalize(y)
plt.plot(x,y)
plt.show()

# %%
"""
with open("low_perturb", "r") as f:
    s = f.read()
    data = json.loads(s)
    
times = np.array(list(map(int, data.keys())))
naive_var = np.array([data[str(t)]["naive_var"] for t in times])
plt.plot(times, naive_var)
"""

# %%
def mydot(xx, xy, xz, v):
    assert(len(v)==3)
    return xx*v[0] + xy*v[1] + xz*v[2]

def mycross(xx,xy,xz,v):
    assert(len(v)==3)
    xres = xy*v[2] - xz*v[1]
    yres = xz*v[0] - xx*v[2]
    zres = xx*v[1] - xy*v[0]
    return np.array([xres, yres, zres])

def f_no_hel(xx, xy, xz, k, e, phi, N):
    assert(len(e)==3)
    assert(isinstance(phi, float))
    assert(isinstance(N, float))
    
    pref = N/np.sqrt(np.dot(k,k) - np.dot(k,e))
    cross = np.cross(k,e)
    dot = mydot(xx,xy,xz,k)
    print(dot.shape)
    print(cross.shape)
    fx = np.cos(pref * cross[0] *(dot + phi))
    fy = np.cos(pref * cross[1] *(dot + phi))
    fz = np.cos(pref * cross[2] *(dot + phi))
    return (fx, fy, fz)

xinds = arange(0,128)*0.049087
xx, xy, xz= meshgrid(xinds,xinds,xinds)

phi = 1.0
N = 1.0
k = np.array([1,2,1], dtype=np.float)
e = np.array([1,1,1], dtype=np.float)
k /= sqrt(sum(k**2))
e /= sqrt(sum(e**2))
print(k)

fx, fy, fz = f_no_hel(xx,xy,xz,k,e,phi,N)

mag = sqrt(fx*fx + fy*fy + fz*fz)
for i in [0,1,2,10,100]:
    plt.imshow(mag[:,i,:])
    plt.colorbar()
    plt.show()

# %%
def next_int(x,c):
    return (x) + c-(x)%c

for i in range(20):
    print(i, next_int(i,2))

# %%
baserun_len = 20000
baserun_dump_freq = 1000
perturbation_len = 3
perturbation_dump_freq = 1
final_len = 100
final_dump_freq = 5

# x+c-x%c is the first number strictly bigger than x that is divisible by c
def next_int(x,c):
    return x+c-x%c

baserun_dump_steps = range(0,baserun_len+1, baserun_dump_freq)
perturbation_dump_steps = range(next_int(baserun_len,perturbation_dump_freq), baserun_len+perturbation_len+1, perturbation_dump_freq)
final_dump_steps = range(next_int(baserun_len+perturbation_len, final_dump_freq), baserun_len+perturbation_len+final_len+1, final_dump_freq)

for i in baserun_dump_steps:
    print(i)
print("====")
for i in perturbation_dump_steps:
    print(i)
print("====")
for i in final_dump_steps:
    print(i)
print("====")

# %%
for k,v in locals().items():
    if len(k)<=3:
        print(k,str(v)[:10])
